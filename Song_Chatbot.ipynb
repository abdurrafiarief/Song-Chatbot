# %% [markdown]
# <a href="https://colab.research.google.com/github/abdurrafiarief/Song-Chatbot/blob/main/Song_Chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Sumber dataset https://www.kaggle.com/imuhammad/audio-features-and-lyrics-of-spotify-songs
# https://docs.google.com/document/d/1DPdsfIHn1nFRBsNYk1oId3KooaP8uQfek6noMv_3g3g/edit
import numpy as np
import nltk
import pandas as pd
import re

# %%
# !pip install pyspellchecker
# Out:
# Requirement already satisfied: pyspellchecker in /usr/local/lib/python3.7/dist-packages (0.6.2)

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
print(open('spotify_songs.csv'))
# Out:
# <_io.TextIOWrapper name='spotify_songs.csv' mode='r' encoding='UTF-8'>

# %% [markdown]
# # Pre-processing

# %% [markdown]
# ## **[Filter based on language]**
# ---

# %%
df = pd.read_csv('spotify_songs.csv', encoding='UTF-8')
sorted = df.loc[df['language'] == 'en']
sorted = sorted[['track_id','track_name','track_artist','lyrics','playlist_genre','playlist_subgenre','track_popularity']]
sorted = sorted.dropna()
sorted.to_csv('data.csv',index=False)

# %% [markdown]
# ## **[Tokenization]**
# ---

# %% [markdown]
# ### Cleansing lyric from contractions

# %%
# Dictionary of english Contractions from https://www.analyticsvidhya.com/blog/2020/08/information-retrieval-using-word2vec-based-vector-space-model/ 
contractions_dict = { "ain't": "are not","'s":" is","aren't": "are not","can't": "can not","can't've": "cannot have",
"'cause": "because","could've": "could have","couldn't": "could not","couldn't've": "could not have",
"didn't": "did not","doesn't": "does not","don't": "do not","hadn't": "had not","hadn't've": "had not have",
"hasn't": "has not","haven't": "have not","he'd": "he would","he'd've": "he would have","he'll": "he will",
"he'll've": "he will have","how'd": "how did","how'd'y": "how do you","how'll": "how will","i'd": "i would",
"i'd've": "i would have","i'll": "i will","i'll've": "i will have","i'm": "i am","i've": "i have",
"isn't": "is not","it'd": "it would","it'd've": "it would have","it'll": "it will","it'll've": "it will have",
"let's": "let us","ma'am": "madam","mayn't": "may not","might've": "might have","mightn't": "might not",
"mightn't've": "might not have","must've": "must have","mustn't": "must not","mustn't've": "must not have",
"needn't": "need not","needn't've": "need not have","o'clock": "of the clock","oughtn't": "ought not",
"oughtn't've": "ought not have","shan't": "shall not","sha'n't": "shall not",
"shan't've": "shall not have","she'd": "she would","she'd've": "she would have","she'll": "she will",
"she'll've": "she will have","should've": "should have","shouldn't": "should not",
"shouldn't've": "should not have","so've": "so have","that'd": "that would","that'd've": "that would have",
"there'd": "there would","there'd've": "there would have",
"they'd": "they would","they'd've": "they would have","they'll": "they will","they'll've": "they will have",
"they're": "they are","they've": "they have","to've": "to have","wasn't": "was not","we'd": "we would",
"we'd've": "we would have","we'll": "we will","we'll've": "we will have","we're": "we are","we've": "we have",
"weren't": "were not","what'll": "what will","what'll've": "what will have","what're": "what are",
"what've": "what have","when've": "when have","where'd": "where did",
"where've": "where have","who'll": "who will","who'll've": "who will have","who've": "who have",
"why've": "why have","will've": "will have","won't": "will not","won't've": "will not have",
"would've": "would have","wouldn't": "would not","wouldn't've": "would not have","y'all": "you all",
"y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
"you'd": "you would","you'd've": "you would have","you'll": "you will","you'll've": "you will have",
"you're": "you are","you've": "you have"}
contractions_re=re.compile('(%s)' % '|'.join(contractions_dict.keys()))

def expand_contractions(text,contractions_dict=contractions_dict):
    def replace(match):
        return contractions_dict[match.group(0)]
    return contractions_re.sub(replace, text)

def cleansed_docs(doc):
  x = pd.Series([i.lower() for i in doc])
  return x.apply(lambda x:expand_contractions(x))

lyrics = cleansed_docs(sorted['lyrics'])
titles = cleansed_docs(sorted['track_name'])
lyrics
# Out:
# 0        the trees, are singing in the wind the sky blu...
# 1        na yeah, spyderman and freeze in full effect u...
# 2        i really can not stay baby it is cold outside ...
# 3        get up out of my business you do not keep me f...
# 4        hold your breath, do not look down, keep tryin...
#                                ...
# 15400    yeah, nah, nah, nah, nah, nah, nah, nah, nah n...
# 15401    caught up in such a head rush, wide-eyed latel...
# 15402    my anaconda do not, my anaconda do not my anac...
# 15403    bound, bound bound, bound bound to fall in lov...
# 15404    (would you do for me) sweetheart (would you do...
# Length: 15405, dtype: object

# %%
def tokenize_docs(doc):
  output = []
  for i in doc:
    token = nltk.tokenize.word_tokenize(i)
    clean_token = []
    for i in token:
      if str.isalnum(i):
        clean_token.append(i)
    output.append(clean_token)
  return output

# %% [markdown]
# ### Tokenize lyric and titles

# %%
tok_lyric = tokenize_docs(lyrics)
tok_lyric[0]
# Out:
# ['the',
#  'trees',
#  'are',
#  'singing',
#  'in',
#  'the',
#  'wind',
#  'the',
#  'sky',
#  'blue',
#  'only',
#  'as',
#  'it',
#  'can',
#  'be',
#  'and',
#  'the',
#  'angels',
#  'smiled',
#  'at',
#  'me',
#  'i',
#  'saw',
#  'you',
#  'in',
#  'that',
#  'lonely',
#  'bench',
#  'at',
#  'half',
#  'past',
#  'four',
#  'i',
#  'kissed',
#  'your',
#  'soft',
#  'soft',
#  'hands',
#  'and',
#  'at',
#  '6',
#  'i',
#  'kissed',
#  'your',
#  'lips',
#  'and',
#  'the',
#  'angels',
#  'smiled',
#  'i',
#  'thought',
#  'hey',
#  'i',
#  'feel',
#  'alive',
#  'the',
#  'park',
#  'sign',
#  'said',
#  'it',
#  'was',
#  'closed',
#  'and',
#  'we',
#  'jumped',
#  'that',
#  'fence',
#  'with',
#  'no',
#  'cares',
#  'at',
#  'all',
#  'and',
#  'we',
#  'kissed',
#  'under',
#  'a',
#  'tree',
#  'we',
#  'danced',
#  'under',
#  'the',
#  'midnight',
#  'sun',
#  'and',
#  'i',
#  'loved',
#  'you',
#  'without',
#  'knowing',
#  'you',
#  'at',
#  'all',
#  'and',
#  'we',
#  'laughed',
#  'and',
#  'felt',
#  'so',
#  'free',
#  'and',
#  'the',
#  'angels',
#  'they',
#  'smiled',
#  'i',
#  'thought',
#  'hey',
#  'i',
#  'feel',
#  'alive']

# %%
tok_title = tokenize_docs(titles)
tok_title[0]
# Out:
# ['i', 'feel', 'alive']

# %% [markdown]
# ### Tokenize and cleansing artist name

# %%
subt_dict = { "\$": "s","&":" and ","-": " ","!": "i","\/":" ", "'n": " and", "n'": "and", "\.":""}
temp_artist = sorted[['track_id','track_artist']].values.tolist()
new_artists = [] 
for words in temp_artist:
  result = words[1]
  for keys in subt_dict.keys():
    result = re.sub(r'{}'.format(keys),subt_dict[keys],result)
  new_artists.append({words[0]: result})

# %%
tok_artist = []
for dict_word in new_artists:
  for key,values in dict_word.items():
    token = nltk.tokenize.word_tokenize(values.lower())
    clean_token = []
    for i in token:
      if str.isalnum(i):
        clean_token.append(i)
    tok_artist.append({key: clean_token})

# %%
tok_artist
# Out:
# [{'004s3t0ONYlzxII9PLgU6z': ['steady', 'rollin']},
#  {'00chLpzhgVjxs1zKC9UScL': ['bell', 'biv', 'devoe']},
#  {'00cqd6ZsSkLZqGMlQCR0Zo': ['ceelo', 'green']},
#  {'00emjlCv9azBN0fzuuyLqy': ['kard']},
#  {'00f9VGHfQhAHMCQ2bSjg3D': ['james', 'tw']},
#  {'00FROhC5g4iJdax5US8jRr': ['diddy']},
#  {'00GfGwzlSB8DoA0cDP2Eit': ['babyface']},
#  {'00Gu3RMpDW2vO9PjlMVFDL': ['blasterjaxx']},
#  {'00HIh9mVUQQAycsQiciWsh': ['magic', 'city', 'hippies']},
#  {'00i2HU7TEzzftShjRrDSEF': ['2pac']},
#  {'00ITtxUozN0vifE2uYvtqn': ['queen']},
#  {'00LfFm08VWeZwB0Zlm24AT': ['baby', 'bash']},
#  {'00lNx0OcTJrS3MKHcB80HY': ['jax', 'jones']},
#  {'00NAQYOP4AmWR549nnYJZu': ['the', 'weeknd']},
#  {'00OKDIsSQbx8rd5Al7fKNw': ['sabrina', 'carpenter']},
#  {'00p85inzGeXRXgqDVn7Ftq': ['zotiyac']},
#  {'00PLtXXER1XcTRZvs3LioS': ['the', 'brothers', 'johnson']},
#  {'00ppj2gGs8oxhGnTdejkzD': ['saymyname']},
#  {'00qOE7OjRl0BpYiCiweZB2': ['foreigner']},
#  {'00QyLmjxaSEE8qIZQjBXBj': ['2', 'chainz']},
#  {'00ReeHCY0FQUyuAUyPJdnk': ['mc', 'breed']},
#  {'00S35gEf40z03JTJgvQMqi': ['syn', 'cole']},
#  {'00SmB7n85SKROGjybsyq5i': ['manu', 'chao']},
#  {'00UpV14MDfk4CvrMbFvqji': ['sevyn', 'streeter']},
#  {'00WIXhVVhswHuS6dlkScuw': ['confetti']},
#  {'00YeYHw6zhoy1y7EPTgIkj': ['benjamin', 'francis', 'leftwich']},
#  {'00Z0GIRi0l7WqQnQJCo5S2': ['louis', 'tomlinson']},
#  {'011gUcrvLDn2gEApOdOhVe': ['sam', 'feldt']},
#  {'012mGdSYIBEmERuScm2iOl': ['the', 'jackson', '5']},
#  {'014J7jX1wSv0manSdRnveo': ['calum', 'scott']},
#  {'014V6u9VubefjaPPl1QkTJ': ['eminem']},
#  {'01Bw3xiZ5PQfn0btMWICaQ': ['lost', 'frequencies']},
#  {'01DSvNTUsVROjnSF5j3UbD': ['pink']},
#  {'01IQ4aQgOf0Kkq3a273hmO': ['dave']},
#  {'01iyINEYgPQ7ThMZuHUsqS': ['lost', 'kings']},
#  {'01kmEgrTZAGvJNicVB7laT': ['lund']},
#  {'09s7AzC1vXpkIBS8xphJgP': ['shai']},
#  {'09TZsMHXEtQkdmMJZPLKup': ['stunna', '4', 'vegas']},
#  {'09wrW4mdaoBrOFY6KSR94h': ['the', 'blaze']},
#  {'09xGoSMPNhCqctq7x3HN5x': ['fabolous']},
#  {'09yhMTRqQ1I1dniu3PoIQi': ['lost', 'kings']},
#  {'09yLdUZdymzX8iocIUxem5': ['ariana', 'grande']},
#  {'09YXhYMYIHZBHVKGEQrSQF': ['andrea', 'bocelli']},
#  {'0a4agFmqHXxcZl1nho1BxM': ['blondie']},
#  {'0a4vQ58TiGl8Z77EEAvQCx': ['the', 'the']},
#  {'0A52Tcklg6nNjkCNFrHwyM': ['the', 'allman', 'brothers', 'band']},
#  {'0A5gdlrpAuQqZ2iFgnqBFW': ['gaullin']},
#  {'0A5qqtFMG1qrNQEcjvr1A2': ['charli', 'xcx']},
#  {'0AA6zq5ArZ1sSH7VIMi4NK': ['mims']},
#  {'0aAVBcORefVNADGxgqh8XM': ['tritonal']},
#  {'0abrjTBmZ4xiA3seMA4pTu': ['escape', 'the', 'fate']},
#  {'0Acc8Z2mhTiU6ceB4DEyCt': ['xzibit']},
#  {'0aCI9tg8Pb9l1uoOPk9R8n': ['miami', 'horror']},
#  {'0AcLrSfAEBQcUnHOTm5pXg': ['montell', 'jordan']},
#  {'0AcmTuNAihP5wlws9eBwQc': ['safire']},
#  {'0ADG9OgdVTL7fgREP75BrZ': ['zara', 'larsson']},
#  {'0ADZ5dmXhlfzjMw6lefoPl': ['nickelback']},
#  {'0aEb1gDzaQMb53iXXoM7Lj': ['the', 'who']},
#  {'0Aergaee1PD3zbWcjxcUJl': ['the', 'blue', 'stones']},
#  {'0aersVHlGGXcHeRvHtuaSt': ['st', 'lucia']},
#  {'0afhq8XCExXpqazXczTSve': ['ed', 'sheeran']},
#  {'0AGh7lxZOWUhLL0FqrXHjX': ['gawvi']},
#  {'0AGJuICX9Uhne0ER96c4Rw': ['halestorm']},
#  {'0aH8X88VkmMpDK6tGcwRd1': ['annella']},
#  {'0AHHDAHFRaT82UVw5fMr1R': ['parkway', 'drive']},
#  {'0aHOXu219Z4MqEKwiKsddl': ['robin', 'schulz']},
#  {'0AhRPDuVwHkLAACbPXidb3': ['onerepublic']},
#  {'0aHWQ6E8E4YejHS1P3D8t6': ['josh', 'stanley']},
#  {'0AhZNtpPVaC4TApU3H76nL': ['today']},
#  {'0AICBlLzFCTpUqmAbtzB2z': ['trippie', 'redd']},
#  {'0AJ62x1CXjJf3VW25CeZXa': ['led', 'zeppelin']},
#  {'0ak9xScGzG7JaA1BUlLb7S': ['the', 'decemberists']},
#  {'0AKejOKlGdiB53QpwAeenO': ['maroon', '5']},
#  {'0aKNU0pxAon4dXwjY4GreO': ['famba']},
#  {'0aKoR2iMGuqAUBBCdRwII8': ['agar', 'agar']},
#  {'0AkQbXGN4KG34TS7xLrM68': ['one', 'direction']},
#  {'0akznwBCaPCVAtiGblDtHt': ['oceans']},
#  {'0amPDBn2wSRl0vRyWSLk5v': ['hermano']},
#  {'0BXpGF6fx25lpl985KlJMD': ['funk', 'machine']},
#  {'0Bxxg49qYTFt3QDfnyzQYh': ['greg', 'grease']},
#  {'0byab45cmZntz74RxcASrf': ['ellie', 'goulding']},
#  {'0bYg9bo50gSsH3LtXe2SQn': ['mariah', 'carey']},
#  {'0ByMNEPAPpOR5H69DVrTNy': ['rihanna']},
#  {'0c1gHntWjKD7QShC8s99sq': ['aerosmith']},
#  {'0c37uJwj7mpovCAuFY5ofQ': ['glades']},
#  {'0c3fJd2HRi6uHWgTljIae5': ['breaking', 'benjamin']},
#  {'0C3kqX3iJ39GorFVrNcMmi': ['veridian']},
#  {'0C3QADQBYFjcSeU8bY7Oex': ['dombresky']},
#  {'0C4bx13JIMSWOAxd8TaoVq': ['ozzy', 'osbourne']},
#  {'0c4IEciLCDdXEhhKxj4ThA': ['muse']},
#  {'0C5X8RJXZNuGO2CfQJumb5': ['asking', 'alexandria']},
#  {'0C6EIiQu8CS4eYtOCMEiAd': ['depeche', 'mode']},
#  {'0c6SqvH32BMgbEFvpHc2gs': ['the', 'kid', 'laroi']},
#  {'0c6xIDDpzE81m2q797ordA': ['kiesza']},
#  {'0C7dYeCLF6ukChtW64UNge': ['milli', 'vanilli']},
#  {'0c7K73roy6RW4ebDkf4yGh': ['24kgoldn']},
#  {'0C80GCp0mMuBzLf3EAXqxv': ['ac', 'dc']},
#  {'0C80KJWvQWIGjbOiIurV1W': ['ne', 'yo']},
#  {'0c8W8aqdrtM67F3JVIt593': ['lucas', 'and', 'steve']},
#  {'0c8X4ApJu6CNEXoIb5VKMo': ['zeds', 'dead']},
#  {'0C9w0WJdckpqR7w0yEWo2i': ['céline', 'dion']},
#  {'0CA3RxBx2xSQXPfpmUBK1v': ['three', 'days', 'grace']},
#  {'0CAfXk7DXMnon4gLudAp7J': ['flo', 'rida']},
#  {'0cc0C15xFeldpAIkIp440J': ['d', 'block', 'europe']},
#  {'0CCvfFVSpOHGuxsrzfwbYL': ['next', 'town', 'down']},
#  {'0CDoNIHn1ivManl0kloMzj': ['kaptan']},
#  {'0ceeRNqbOzRiGE42KWSrRa': ['tamia']},
#  {'0CEIJwqzXmmWNKDV8NFw60': ['lane', '8']},
#  {'0cELvuwJW1acISUHYB6suj': ['mariah', 'carey']},
#  {'0CeOseGlRvn6zFoMLDvtsa': ['karyn', 'white']},
#  {'0Cevaujuf5Os3lb5KrV0IH': ['hot', 'shade']},
#  {'0ceW5TkemJUEmJERavfqQq': ['bring', 'me', 'the', 'horizon']},
#  {'0cEY2XrkwZAyrxMioyiAQB': ['mc', 'hammer']},
#  {'0cfgMbqcqdDVkooYMhnrV2': ['struggle', 'jennings']},
#  {'0CFIH3diqmPfa6FRXEILLF': ['paul', 'haig']},
#  {'0cge96qsW6ifXppeiiRIGd': ['hardwell']},
#  {'0cGG2EouYCEEC3xfa0tDFV': ['soft', 'cell']},
#  {'0cGKcnXQmiyU5WKubrEmDh': ['don', 'omar']},
#  {'0cGR1le8zMJWt8WcgCyRpv': ['frank', 'zappa']},
#  {'0cgRDeRDPNrfRifO8WHit8': ['eden']},
#  {'0CI422U7nhDLnk43s1BS1F': ['robin', 'schulz']},
#  {'0CIGZEXjZ8L52lOrqUljJt': ['6lack']},
#  {'0CJmYEsImHZ42f7W6ntlX2': ['8ball']},
#  {'0CJwLZDmSFdXL2WcA74Vo3': ['tash', 'sultana']},
#  {'0CJzVKPtJaeOt76jO3PpbZ': ['onerepublic']},
#  {'0cKuO2BdECtbVQDCGx1dqa': ['survivor']},
#  {'0CLhMOVhX6TaPpugYkEsge': ['wiz', 'khalifa']},
#  {'0Clwo8t8LxxExXDJ7AqeVg': ['mc', 'lyte']},
#  {'0CmIALzGn4vHIHJG4n3Q4z': ['etta', 'james']},
#  {'0CMRCkUdmiHGt7EzEUIskU': ['ideladap']},
#  {'0CmXXEwul09Kf8X68lPA5l': ['case']},
#  {'0cNRa6q0dPjckz3SoDGirO': ['darius', 'and', 'finlay']},
#  {'0CNuwuX6yEMcQYsCnwUfaV': ['china', 'anne', 'mcclain']},
#  {'0CObIjO1AMb1GUFbDg9u7h': ['daniel', 'adams', 'ray']},
#  {'0coMLoVcagZPGF5zxc5RF8': ['hardwell']},
#  {'0COqiPhxzoWICwFCS4eZcp': ['evanescence']},
#  {'0CPnwugq0UbmaT19wAbhk8': ['the', 'globetroddas']},
#  {'0CPOpfnSiGwlyLZz2oTQGX': ['robert', 'falcon']},
#  {'0cppqb4vQycORHNMxr8DGd': ['astrid', 's']},
#  {'0Cqm4rlGZw9mUyzVAYHiVf': ['capital', 'cities']},
#  {'0CR60XwKbzgohE3I6NMjlR': ['tyga']},
#  {'0cSJGFChou7M6u2ju9SWN1': ['eric', 'b', 'and', 'rakim']},
#  {'0CsM8VGDi38kusMv3pxyj1': ['spandau', 'ballet']},
#  {'0csUoMvvImqcIPpobc21QU': ['montell', 'jordan']},
#  {'0CT0EoTIp9E1B5JQ0Uq2An': ['11', 'acorn', 'lane']},
#  {'0ct6r3EGTcMLPtrXHDvVjc': ['avicii']},
#  {'0ctMHnma5rklnfurOKFXV0': ['50', 'cent']},
#  {'0cuq829zRNq4AEdmDJA4aw': ['spin', 'doctors']},
#  {'0cVaY6PNGxCPi1gOIapr26': ['more', 'giraffes']},
#  {'0Cw31BoxoJbFPXrT3kUuyj': ['hailee', 'steinfeld']},
#  {'0Cw4EjuGqEqbxOWSy0iIUw': ['kwassa']},
#  {'0Cw5iiA8OHWIhuIIA8u8N5': ['roy', 'jones', 'jr']},
#  {'0CXdfD4s26kKyuPHRACtlY': ['sixn']},
#  {'0Cy7wt6IlRfBPHXXjmZbcP': ['ellie', 'goulding']},
#  {'0cYzIKaobR7yaxjMTRvO6P': ['ugk']},
#  {'0CZ8lquoTX2Dkg7Ak2inwA': ['king', 'princess']},
#  {'0Czb3OCpCYIc43O0lq2M1Y': ['no', 'doubt']},
#  {'0Czg21zFuXypqp9S76d4TC': ['jaydon', 'lewis']},
#  {'0d0ejCZz2r6XHN2dL90rdu': ['wave', 'wave']},
#  {'0D1mT1OcWVqqFg629clZZc': ['tertia', 'may']},
#  {'0D1ZKHo1jI0gzOWZGhlyv3': ['sg', 'lewis']},
#  {'0d28khcov6AiegSCpG5TuT': ['gorillaz']},
#  {'0d2iYfpKoM0QCKvcLCkBao': ['benny', 'blanco']},
#  {'0d2YnyIPgmPQqNSzDg8s8Q': ['staind']},
#  {'0D5CXSUx8GOCHSY8KWgi9h': ['logic']},
#  {'0d6bZwEAi1XblGRhnzPfgC': ['bon', 'iver']},
#  {'0D7DRqVU5h31xtEUccV4s7': ['pentatonix']},
#  {'0D8n26VxzYSDIMhDO5JPjO': ['blanke']},
#  {'0D9z6DQ7UBnp7sPv3y3cgV': ['throttle']},
#  {'0dA2Mk56wEzDgegdC6R17g': ['zedd']},
#  {'0dBatXn1vVUl0jLgXRClwD': ['elton', 'john']},
#  {'0DBIL8arX0Zo6eAuxNIpik': ['r', 'kelly']},
#  {'0dbNRVOII6bCmvfiae3KG1': ['kdl']},
#  {'0dbTQYW3Ad1FTzIA9t90E8': ['lil', 'wayne']},
#  {'0DC5wcWwsGTGlBkVsb6PVe': ['lynyrd', 'skynyrd']},
#  {'0dcf0L6F1LUA1nE2zWH4J2': ['the', 'weeknd']},
#  {'0dCr3qIupWh36ilLjRHi4P': ['jamiroquai']},
#  {'0Dcv1cRaS8sEUYzjHNhHBr': ['mcclenney']},
#  {'0DCxAJasKxjhODdqpF4s36': ['gloria', 'estefan']},
#  {'0dDifktDnbzmGwliFzI0Ld': ['bell', 'biv', 'devoe']},
#  {'0deI3lZkgbVt6wRsv5s0Ev': ['gary', 'moore']},
#  {'0DfqzZnW2KhiyXjVQiFioT': ['2pac']},
#  {'0DgevHFzyhzIWN8hzrO98C': ['roger', 'waters']},
#  {'0DiDStADDVh3SvAsoJAFMk': ['jonas', 'brothers']},
#  {'0DiQAYZAOQLL9mwinkRS3E': ['papooz']},
#  {'0DiWol3AO6WpXZgp0goxAV': ['daft', 'punk']},
#  {'0DJBgfyaAlT7T0i0YAuzrS': ['the', 'mouse', 'outfit']},
#  {'0DKen77OXbPxnoPwH2MH63': ['junior', 'j']},
#  {'0DkF3I1KiN9wcsNw927f7i': ['tujamo']},
#  {'0Dlm41iXvTsIVsEOce3yX6': ['tasha', 'cobbs', 'leonard']},
#  {'0DmuBILb0jSb0pdYGZP1bw': ['austin', 'p', 'mckenzie']},
#  {'0DnA2DyUwy0W4xMYtRxocL': ['men', 'at', 'work']},
#  {'0DNk7lEqDGCN6nDD0H8emF': ['jp', 'cooper']},
#  {'0DnrHiLuf4GrIYq5nk6Gks': ['major', 'lazer']},
#  {'0dnx2LK0rnPTACGzbLc1Jx': ['halestorm']},
#  {'0DO5Qkdbtym514lDNy6LC2': ['kool', 'g', 'rap', 'and', 'dj', 'polo']},
#  {'0DosTwoHVAziTd3GfQNIef': ['killy']},
#  {'0dowxVQPIR50MS1lqLE0om': ['john', 'de', 'sohn']},
#  {'0DPkIJha3NGgjPdC9hNyk6': ['brasstracks']},
#  {'0DPNRRkWkye2ZHTqAiClRH': ['ice', 'cube']},
#  {'0DpVOA3h2uSixj1TrXXfSh': ['def', 'jef']},
#  {'0DQtwZLpvln583U1WWv6To': ['the', 'rolling', 'stones']},
#  {'0dSE54vYYvRNWzVTxE2xTL': ['exid']},
#  {'0DskSLv9ocz7KsJlqUSCGw': ['mavrick']},
#  {'0Dtwxkkn8fJKtqtea7fd1C': ['martin', 'solveig']},
#  {'0DURckDH8F3pzTz7KKFLz7': ['deee', 'lite']},
#  {'0DvhfhHlIE4HqgBX8yDJz3': ['young', 'rising', 'sons']},
#  {'0dvu4Irbq0SM5BWny30rRR': ['gashi']},
#  {'0Dw3M1B14FRabDfVYr5pEX': ['motorama']},
#  {'0DW5anNzTO7h0OlKqFsVQ6': ['david', 'banner']},
#  {'0dw7G0QDuW7UwyL0boHKMU': ['the', 'wanted']},
#  {'0Dw7uVJBAKCm6dfCoabJV9': ['jeff', 'bernat']},
#  {'0Dy3aMQAna0aff0J7tud1M': ['teitur']},
#  {'0DYFK6GnldzwhuA2wwAnmn': ['pixies']},
#  {'0DzwkXawqzpt0k7jxjfdEf': ['ram', 'jam']},
#  {'0E0ZAWynZx0CutIg4rb8q3': ['pj', 'harvey']},
#  {'0e3dpXiKdTHRNXZHdfM2JM': ['another', 'bad', 'creation']},
#  {'0E3L4BNuUlZyvcZyySTfKr': ['dj', 'snake']},
#  {'0e4xfVTScciruWRTHG3Myh': ['klangkarussell']},
#  {'0e6Je5EfLQ7uS9eVqvKTHW': ['rick', 'ross']},
#  {'0E6PsO3ymCfUh7pJQjBgkj': ['the', 'carters']},
#  {'0e6pxMzwePXAxNuNzkmG3R': ['christian', 'kuria']},
#  {'0e7ipj03S05BNilyu5bRzt': ['post', 'malone']},
#  {'0E8WJOFs2eWD67USh7C6Qd': ['loud', 'luxury']},
#  {'0EA7tn6U2YpoUIOjN3AP02': ['banners']},
#  {'0eaZbB3SewakRxB9uHKjjj': ['yes']},
#  {'0EbNfrtewVrVYzHKBArtyv': ['john', 'legend']},
#  {'0ebnzIUpJu8QHyt1oy2S87': ['grendel']},
#  {'0Ed7MeXx64f6OcIuoTRCg1': ['dr', 'dre']},
#  {'0EDfF4djtCu48KZtSHx5jW': ['hayden', 'james']},
#  {'0EDQwboQDmswDRn58wcslg': ['faye', 'webster']},
#  {'0eeeyCAGnGZInPtpkdYiPa': ['bts']},
#  {'0efgEM1LQDbK43rqPH2Iyd': ['ghostemane']},
#  {'0eFvoRSTTaR2q8bSWVjwfp': ['guns', 'n', 'roses']},
#  {'0egGmGkZ8maYdEYo4RrVsZ': ['lil', 'dicky']},
#  {'0EgigrGFGb4PHaVNb7fgK7': ['lil', 'scrappy']},
#  {'0EgmhYPgButfoBvtnidyR0': ['noname']},
#  {'0EGuSSpuu9wmHCtvb4PdLO': ['daya']},
#  {'0egYMfS7hjEneR86a9K61w': ['morrissey']},
#  {'0eHFPf7gom9ztF7Jc6FP6C': ['smokepurpp']},
#  {'0eHoJnbBBwhx4A1JFNcENC': ['kshmr']},
#  {'0EHR9OObFtjlhQB8wSt1m7': ['lil', 'wayne']},
#  {'0EHzXpyi1swR8sMpbVHcLJ': ['guns', 'n', 'roses']},
#  {'0eIy2FGcdMJDewVL96R9ha': ['siks']},
#  {'0EJlpO8Z5Vqy4phgcqU84V': ['matthew', 'parker']},
#  {'0eJzykWzPq1TW7hrvMxKc9': ['d12']},
#  {'0EkB09i9ohIUnsw45jzEyf': ['yael', 'naim']},
#  {'0ekRt9Sc1ukWhAlyEyksuU': ['mike', 'posner']},
#  {'0eKRwDBVWxCXWpLYFYrbd1': ['new', 'order']},
#  {'0elb6lDN4B5Ao3TWoXYUzs': ['wankelmut']},
#  {'0ELVXVHz8aPgwLySfkDn8e': ['obadiah', 'parker']},
#  {'0elXIl26ZrovBULLTrEGK6': ['jaymes', 'young']},
#  {'0EM0yABJzbFOvZQkfvuvCy': ['kaytranada']},
#  {'0EP3yjbjHdbUL1miyNlgys': ['jake', 'isaac']},
#  {'0EPqqVrZZw00uLDTB0pxs6': ['loud', 'luxury']},
#  {'0ePV5nJT0v9wFHjKvt9fNV': ['rkcb']},
#  {'0eq2B9lsa8hhyYLzxPOnLl': ['david', 'guetta']},
#  {'0EQeui6OBMzqJ3Z3wCOzZh': ['faustix']},
#  {'0eqH0ALoDQevq59YcQ53KE': ['gwen', 'stefani']},
#  {'0eqJ0Ok26iVYMV5K7m521l': ['lulleaux']},
#  {'0eQjA54TJkwTHDJKG8OkRg': ['kings', 'of', 'leon']},
#  {'0eQJy4VAW7AkhKIHzXx3jG': ['astrid', 's']},
#  {'0EqtsCvcDjEz6svFsaV5HN': ['aimee', 'mann']},
#  {'0eti3iRdEgUxwcIcN2N9DY': ['van', 'morrison']},
#  {'0Etl0p4Z6doS0xFxqdhrOn': ['tinariwen']},
#  {'0eTX0DeAdYZGCUIpUNNbLw': ['alunageorge']},
#  {'0eujYjPqb8aZfFD17ivy2Q': ['solange']},
#  {'0EvsLFtgq2ToSaH8UXmPK0': ['silkk', 'the', 'shocker']},
#  {'0ew27xRdxSexrWbODuLfeE': ['diana', 'ross']},
#  {'0EwaWLbMW0Tq84YVFNxNsd': ['jodeci']},
#  {'0EWT5JnKOf6saRn4ASff3j': ['mary', 'j', 'blige']},
#  {'0eWxDnXDbsR4h1kVk6rZdy': ['zacari']},
#  {'0EX00YpFv3ivweoG7T3j2n': ['ginuwine']},
#  {'0Exfrf3nRw9SXpls2n8KFB': ['onefour']},
#  {'0exKMPo2iind68yWTaHCrr': ['leon', 'bridges']},
#  {'0eXU92qkEfIWu4SQOILFU3': ['gawvi']},
#  {'0EYZTPdmYkj9Z2q95SepDx': ['g', 'unit']},
#  {'0ez8HT7qqmwMd9wY7PUAuW': ['deamn']},
#  {'0eZElvtraNNWjjRnwiIM6B': ['chico', 'debarge']},
#  {'0F0imGVd7KnvQPkBmVtPo9': ['new', 'order']},
#  {'0f0k0OJ9VbaLHX4J1t2qUy': ['the', 'cranberries']},
#  {'0F0MA0ns8oXwGw66B2BSXm': ['david', 'bowie']},
#  {'0F0Y6RxLpOo86HMFmShOMF': ['stefflon', 'don']},
#  {'0FMMLKHb74VB0H5u2fP6xo': ['jazz', 'liberatorz']},
#  {'0fMMtO0pOYIGWfbJmrqfVJ': ['dillon', 'francis']},
#  {'0fmsS6mNtTTKjsBTXoh0KN': ['benjamin', 'booker']},
#  {'0FNbtFy7loRI7jZC7QZETm': ['jimi', 'hendrix']},
#  {'0FOPDqF7FBZwHITfKHMvLK': ['grandtheft']},
#  {'0fOv9Usm5mbJ0H1EQ7zrIQ': ['snoop', 'dogg']},
#  {'0FP2R9giDksk3a1GUQLfOz': ['ghostemane']},
#  {'0FpF0xdbJDpIZ0wA2OjNku': ['ludacris']},
#  {'0FPXDopNoeVy2GmE6ZLrv1': ['mc', 'lyte']},
#  {'0fpzjL5pP2M8sWifmQqLZn': ['logic']},
#  {'0fqKsU4Hsnb0oKlyjat9da': ['musiq', 'soulchild']},
#  {'0fQuzbQNLcD1ofo7B2NcFI': ['coldplay']},
#  {'0fRsAGSCbEjdSYM1U3NYx2': ['vic', 'mensa']},
#  {'0frzpcv2zCUk13mn0X824T': ['gucci', 'mane']},
#  {'0fScVCIlDvKJYB550Fp8rM': ['the', 'internet']},
#  {'0fsj3HxzBHev6EJ7OLFE3r': ['foreigner']},
#  {'0FsqhyyHNZJfK29IpHihMK': ['john', 'legend']},
#  {'0FssM3rIyBe3fZ02i3hYdy': ['idaly']},
#  {'0fTiDOXRNEN0lUeYGoSHml': ['the', 'chainsmokers']},
#  {'0fTx5ET8US1Bh33OBFeugm': ['adam', 'calhoun']},
#  {'0fUeXvuwXDKRNqvrxveHWF': ['albert', 'king']},
#  {'0FuTx2s3YH1ppmtiM6l0zI': ['jp', 'cooper']},
#  {'0FviQvrqHxxFnR2p6bVOwp': ['scorpions']},
#  {'0FWRA2sewbJ491kmjRRFw6': ['starship']},
#  {'0fXTcou0FQxSGksz3phLfT': ['louis', 'the', 'child']},
#  {'0fxU0Wr9laBGaNsrwJ07Pz': ['today']},
#  {'0FyBloIEdLS3f3SodFiju1': ['drake']},
#  {'0fyBYsrmpihh1mfalssDlB': ['suicideboys']},
#  {'0fySG6A6qLE8IvDpayb5bM': ['dababy']},
#  {'0FZ4Dmg8jJJAPJnvBIzD9z': ['kodak', 'black']},
#  {'0FZTAm6OyJoAzAtLAsH0f9': ['bj', 'the', 'chicago', 'kid']},
#  {'0G0THcz2N4UpY4A6GhgMsN': ['rozes']},
#  {'0G1HcY6dlx8yjJBMCO9rOc': ['ysn', 'flow']},
#  {'0g3mziWGH7OP6lZvKq7Xpi': ['farr']},
#  {'0g5EKLgdKvNlln7TNqBByK': ['dj', 'snake']},
#  {'0g6NSuyHTmz4DLwoGt5Fil': ['jamie', 'woon']},
#  {'0G7Ik0gmxJBFJKAmK2p1k9': ['astrid', 's']},
#  {'0g9NUt0uI1HSWgkLynXRbP': ['fire', 'from', 'the', 'gods']},
#  {'0gaMmmhGi5buPXpquSAfxg': ['rainbow']},
#  {'0gb1J5UrTpzaU1s3nupgCd': ['galantis']},
#  {'0gbedKbKjiLj47RCTM94s5': ['dada', 'life']},
#  {'0GbN4lapADSramCU7SdunV': ['five', 'finger', 'death', 'punch']},
#  {'0GCh3K0s5opTzyU1mpdsSU': ['50', 'cent']},
#  {'0gDh8XfKdq9of5fxuyayq2': ['50', 'cent']},
#  {'0GDVj31c8AxWXjWFzVFu0d': ['sebastian', 'ingrosso']},
#  {'0gDyuX5rdHulQTUyrIdSR1': ['john', 'lennon']},
#  {'0GE84jMHPkH9GfBh67DyYL': ['the', 'years', 'gone', 'by']},
#  {'0gEcmyKlIUoi3sHTFVO1bE': ['tobi', 'lou']},
#  {'0gEyKnHvgkrkBM6fbeHdwK': ['the', 'cranberries']},
#  {'0GfS3y8Jd7SHWd9R51s7Fo': ['sam', 'smith']},
#  {'0GFXbdgwVYO8Dw6BG8MLfL': ['echosmith']},
#  {'0gGJO7JM51uAUu7EE2lxx6': ['rainbow']},
#  {'0GIOPJKTSxagq3rq07Ch3U': ['bryan', 'adams']},
#  {'0gIZLyF3MWQVcspzrLWYod': ['fannypack']},
#  {'0gJO3qjzYbIhoHFRtArifw': ['a', 'flock', 'of', 'seagulls']},
#  {'0gJvqi9QyASOCtJu99tytc': ['kelly', 'clarkson']},
#  {'0GjzyfE9VVSVVkheoweAGs': ['electric', 'light', 'orchestra']},
#  {'0gl8mWugSfOQqL485CzKAj': ['tlc']},
#  {'0glI0Qi04BEuaNWNh5Wytr': ['smallpools']},
#  {'0gmbgwZ8iqyMPmXefof8Yf': ['nickelback']},
#  {'0GNbF413D1n8yS2vLpOBhl': ['currensy']},
#  {'0gnddNB2gbyN8VC7uqr6ns': ['icehouse']},
#  {'0gnG4oD2rOoPWTSzZnnX4A': ['electric', 'guest']},
#  {'0GNlKuzh7ZJTJ1iigkQEVp': ['anything', 'box']},
#  {'0GO8y8jQk1PkHzS31d699N': ['grouplove']},
#  {'0gof4zJewt0Krlibe7egiR': ['cheap', 'trick']},
#  {'0GoXEhMzYwI1LCaohRqxGl': ['whiskey', 'myers']},
#  {'0Gpq0lllEPZf98gVo9C4uS': ['jungle']},
#  {'0gPQTLaqHDgdupKEok7J2x': ['craig', 'david']},
#  {'0Gql9hTkMSka2wbWxworri': ['van', 'halen']},
#  {'0GQuzKlkH0otZ01oMFzsSu': ['guns', 'n', 'roses']},
#  {'0GrcPg89CPjXEkPAsAooGP': ['nico', 'vega']},
#  {'0GRoERSBBky3YgdKW2w2Vc': ['don', 'diablo']},
#  {'0GRu2odJjampqZpyubbFU6': ['rev', 'theory']},
#  {'0gsDBm94QELEJAcGS59f1b': ['marshmello']},
#  {'0GSguwVydcDTrHPoQsS8FU': ['ghost']},
#  {'0gT00heO9IfOUFwdkcIOVH': ['jim', 'james']},
#  {'0gTAcOg1yS6KY3eMaYlpKg': ['apollo', 'ltd']},
#  {'0GTK6TesV108Jj5D3MHsYb': ['yes']},
#  {'0gtTfaz5zzbJA28Ypu7k0W': ['king', 'floyd']},
#  {'0GuQcX8wTe8bUZ72ZncR7m': ['jimi', 'hendrix']},
#  {'0gv9o9mPK1JQeZd3eMFdTa': ['steve', 'aoki']},
#  {'0gVcjxsmYDOw7V1whWHYoZ': ['owl', 'city']},
#  {'0Gx6SVfpMCyjWjA15t124N': ['6o']},
#  {'0Gx7phIMvHVT7pXk03h0rH': ['ari', 'lennox']},
#  {'0GxQ1A5L9xnMOytbP6eKBG': ['maroon', '5']},
#  {'0gYkWzRcwMTs9YXWl0Rghm': ['all', 'time', 'low']},
#  {'0gZp88SA5OcujHLDGkxtI3': ['yellowcard']},
#  {'0gzqZ9d1jIKo9psEIthwXe': ['u2']},
#  {'0h1JeQYLocnVXdexyRuxGH': ['matroda']},
#  {'0h1UKhueXm1YFLpQjzwv0E': ['zedd']},
#  {'0H3NcINi4I8Cd87FO5OUtq': ['the', 'him']},
#  {'0h4FK0CnlZ3oJnZ6quEk1P': ['seeb']},
#  {'0h5m65o5KnMFB4Gq47mbKt': ['50', 'cent']},
#  {'0H6vpbW0UOtVpm3RgiwSkx': ['collie', 'buddz']},
#  {'0h7lem3jmeZbW7wa0q9k16': ['derek', 'and', 'the', 'dominos']},
#  {'0HaAoQJ1PgF0gIm1o6JYIM': ['pastor', 'troy']},
#  {'0hCB0YR03f6AmQaHbwWDe8': ['led', 'zeppelin']},
#  {'0hcnAHsZFmWhZHFjdPshUR': ['unodavid']},
#  {'0hcW7qPqWWJc8189OaqQvX': ['jesse', 'powell']},
#  {'0hdiDzQu1FsfaYM1NIL8ma': ['tyga']},
#  {'0HEmnAUT8PHznIAAmVXqFJ': ['george', 'michael']},
#  {'0HeTpk89fOwfTBVL5d2acE': ['nause']},
#  {'0HFx7PLqzGxSfN59j3UHmR': ['jason', 'derulo']},
#  {'0hGH0S74Eoyv6mXZcOKtdQ': ['post', 'malone']},
#  {'0HgIbfeOw6dLuGmPippTlh': ['clean', 'bandit']},
#  {'0hHR7DwdbnMHPzfWRIOhny': ['8ball']},
#  {'0hiFoxxMg36FoPIdmiAyfX': ['shura']},
#  {'0hioWv2FDtVePjHFTwgrf7': ['ll', 'cool', 'j']},
#  {'0HjdsfmhSJmGYt2L3BO5jR': ['eminem']},
#  {'0HjiQYZdHqrKyfeQL3JYw3': ['johnny', 'gill']},
#  {'0hK0PTJdd4Jx6Ryl4t8jTi': ['lost', 'kings']},
#  {'0Hk1zuUABam9U5M634R0Fv': ['manu', 'crooks']},
#  {'0hKbBE3RwBZQtsnkzBIxIR': ['muna']},
#  {'0HkcFsicQMIumVpNNde204': ['raheem', 'devaughn']},
#  {'0hKF8N8aflF1uDzEEnPr2j': ['tom', 'cochrane']},
#  {'0hKRSZhUGEhKU6aNSPBACZ': ['the', 'beatles']},
#  {'0HkwDCJIbWijtfKg63gQBJ': ['möwe']},
#  {'0HLpIMwRnkDSn55nAhscB9': ['olly', 'murs']},
#  {'0hMmCpvgtjF8ZUsbl2x0Cg': ['moonchild']},
#  {'0hMNAUx9fFBdYQRO5FoQvL': ['eric', 'clapton']},
#  {'0hmQY8NW6hNQWfkvZsa1e9': ['gucci', 'mane']},
#  {'0hmxVkpxbcdHAXUoZ7DeCQ': ['the', 'voidz']},
#  {'0hNduWmlWmEmuwEFcYvRu1': ['petit', 'biscuit']},
#  {'0hnHoQbEQOL4YUZ4SO6xbe': ['china', 'anne', 'mcclain']},
#  {'0hnlRgTh80b1emNnM0jmwt': ['jimi', 'hendrix']},
#  {'0hOA8SoraNo2ZP1amtVYnY': ['fleetwood', 'mac']},
#  {'0hOAqVCzjzNpZgZZmt30HE': ['drew', 'ryan', 'scott']},
#  {'0HOqINudNgQFpg1le5Hnqe': ['geto', 'boys']},
#  {'0hpaWop2LUln6yJ7b0eOza': ['dermot', 'kennedy']},
#  {'0HPD5WQqrq7wPWR7P7Dw1i': ['kesha']},
#  {'0hPFPELRHZetjzU7dIaBqj': ['geto', 'boys']},
#  {'0hrBpAOgrt8RXigk83LLNE': ['ace', 'of', 'base']},
#  {'0hrRcmdet5Ey4GqwnM0wBI': ['and', 'one']},
#  {'0HRSsZiisdMuUrWhzb8ewK': ['wiz', 'khalifa']},
#  {'0HsE2zUH1uZg7Bnsjf51TM': ['knox', 'hamilton']},
#  {'0HSHOXIDMwhFbXHnaxpvxE': ['martin', 'garrix']},
#  {'0hsMhZA3gguNuHOcDsGmOf': ['little', 'giants']},
#  {'0HsTJZWuj9vY7Ns0If1ARm': ['tonyi', 'tonii', 'tonéi']},
#  {'0hTiTU0yqthnByyZDD3bcc': ['volbeat']},
#  {'0HUeFoQFiMUPKxFApxyPwL': ['destiny', 'rogers']},
#  {'0hur9YKoUq3uwte8K30zlC': ['maddix']},
#  {'0hv6ku4431kPrjbpBBspw3': ['martin', 'garrix']},
#  {'0HVj61S4pQJdQhgZP61G65': ['zara', 'larsson']},
#  {'0HvrW09sl0aoAEmlIcZ9s6': ['amy', 'winehouse']},
#  {'0hvxqftYCZT406ElE03giM': ['channel', 'live']},
#  {'0hVXuCcriWRGvwMV1r5Yn9': ['ed', 'sheeran']},
#  {'0hwkukpHcBJfGcIUxi1tK2': ['ynw', 'melly']},
#  {'0HZ3OUVrGHxttD2EuHqRm3': ['hale']},
#  {'0HZlND4giwzgolBpaNIRGV': ['the', '5th', 'dimension']},
#  {'0i00AL9toLfJeb4VlWLvSi': ['gloria', 'estefan']},
#  {'0I0CVZi0p78WJMDftfXeGM': ['then', 'jerico']},
#  {'0I0onONP8E5RG8oxpWoGIY': ['the', 'kooks']},
#  {'0I0VDjGtm7F1lu5UiinV1b': ['johnny', 'kemp']},
#  {'0i19MAZbyn8uTir7FprXId': ['the', 'velvet', 'underground']},
#  {'0I3q5fE6wg7LIfHGngUTnV': ['outkast']},
#  {'0i3utbege8Iy3q7Hy86QCF': ['gostan']},
#  {'0I3wlS5dlpw0hv5zhxN0pz': ['retrovision']},
#  {'0i5el041vd6nxrGEU8QRxy': ['florida', 'georgia', 'line']},
#  {'0i5LBaRAugIBpBMEfNvN0e': ['nitzer', 'ebb']},
#  {'0I7EJmk6S47mpVh73dB02r': ['ludacris']},
#  {'0i8JFpqe9cKwnrcvoNgl1L': ['skillet']},
#  {'0IBgCsG8dRnUtveiIaoFHF': ['dru', 'hill']},
#  {'0iBGgTRtJU8XEjdRL8ZFQi': ['the', 'knocks']},
#  {'0iBOGfVW1T08dRqtqnMYK0': ['aj', 'mitchell']},
#  {'0IBUFi55OCMR5HrDHB1lEo': ['sam', 'and', 'dave']},
#  {'0ibYVniVLMJWvc3eNfYk8T': ['real', 'mccoy']},
#  {'0iCt0wDnoMe4Eg9Cy2zwqc': ['proper', 'dos']},
#  {'0idc0XRnLRovVqpWnGQ6hC': ['route', '94']},
#  {'0IDcqQM84frBhAJ8vXC76I': ['seinabo', 'sey']},
#  {'0IdNBZt0O8R9qBgezYFGOi': ['disturbed']},
#  {'0IeFn6mSeSiXvB2dGgpdEI': ['hayden', 'james']},
#  {'0IEvbpIyDb26zwhnFGzuLb': ['big', 'mike']},
#  {'0ifIudDeWelhhKzNqP12jm': ['the', 'pretty', 'reckless']},
#  {'0IhHkW1fnUSMEcLSHmKhrJ': ['tevin', 'campbell']},
#  {'0iHO8dmXhSYCgfow7ckt9W': ['james', 'arthur']},
#  {'0IK8y0vAO0sM630HsxwLht': ['bohnes']},
#  {'0IKK48xF4eEdfofyaeKWWO': ['zayn']},
#  {'0IkKz2J93C94Ei4BvDop7P': ['lmfao']},
#  {'0IMQFfmMikvJge5bweNVxe': ['jarryd', 'james']},
#  {'0iPy1MWCrOT7SjGs14zSSv': ['earth', 'wind', 'and', 'fire']},
#  {'0iQ77tSa7ncj7zBPtVx6cU': ['walk', 'the', 'moon']},
#  {'0iRk0TRxGqhQT9FTTGDQlb': ['from', 'inside']},
#  {'0iRXwSL6X0Fhya8Xk8kNhl': ['maceo']},
#  {'0IRz5I01411GsTnepuXtUp': ['tender']},
#  {'0IsrDyDQyNFFNB55MXgnkU': ['the', 'aces']},
#  {'0It6VJoMAare1zdV2wxqZq': ['muse']},
#  {'0Iu5gAorcdocbx2Nz5Vos5': ['bankrol', 'hayden']},
#  {'0ivarc4umuzp5I3J7lPDJc': ['guns', 'n', 'roses']},
#  {'0IvaxIhE6z3QGtQZoDDfFl': ['teen', 'beach', 'movie', 'cast']},
#  {'0iwsQWgtjSq2kUXuZwTDAL': ['madison', 'beer']},
#  {'0iWYUegJm3Ty16VEp69HLs': ['the', 'chainsmokers']},
#  {'0ix3RUQ76mECOKP6LDPy66': ['stormzy']},
#  {'0IXpUl1fn2QZcBavfuq0H4': ['judas', 'priest']},
#  {'0iYebKFUSfF72fUu2OW6ZT': ['nicki', 'minaj']},
#  {'0iyFMU2QF4a2SmAeCwf3it': ['scorpions']},
#  {'0IZoBFaTUG79KBfKlv8zmG': ['smith', 'and', 'thell']},
#  {'0J0busYTWpcKAcryFukUuk': ['aria']},
#  {'0J1mcDz3wZTdBeZ56ho8LN': ['birdman']},
#  {'0j3dGGZBTRa3hZubKT9n7M': ['the', 'plug']},
#  {'0J45lEzyh0cMdi4jPAp5xV': ['gucci', 'mane']},
#  {'0j5X6DrzkgY64Mm8NQp5mi': ['eminem']},
#  {'0J6mQxEZnlRt9ymzFntA6z': ['bon', 'jovi']},
#  {'0jakaHRU7ubOzJTseh6tJu': ['pouya']},
#  {'0jBE7Fn78EAvmIs3dCd6GO': ['the', 'strokes']},
#  {'0jBJIQuToUUOEx7JJkiPzm': ['flipp', 'dinero']},
#  {'0Jci9dBlCSDgL5ivMMSAQx': ['creedence', 'clearwater', 'revival']},
#  {'0Jcnr8HUGQdaOiSkqpdEKX': ['anna', 'margaret']},
#  {'0jCVWQsoQM4UDvd4OyQbA2': ['killswitch', 'engage']},
#  {'0jdeEv8NTDoB2uetW1wXPO': ['pebbles']},
#  {'0jdso14vaFnpRazMLEZovF': ['masked', 'wolf']},
#  {'0jET2Wl3JrzW2XCsFZza6i': ['chris', 'botti']},
#  {'0jFwcP1btVnq7z5KkE0ar9': ['safire']},
#  {'0Jg602cHeMCnPez9baacIe': ['rednex']},
#  {'0jG92AlXau21qgCQRxGLic': ['missy', 'elliott']},
#  {'0jgVkOMLMRZTgx06ddo4DQ': ['nancy', 'wilson']},
#  {'0jgXVGgqgU5ugcsR0J5mbo': ['black', 'sabbath']},
#  {'0jHkgTtTaqg5LNCiYDQPUB': ['marvin', 'gaye']},
#  {'0JhKJg5ejeQ8jq89UQtnw8': ['avicii']},
#  {'0JHwXSvHa9X1UdcKCDAwSg': ['kid', 'runner']},
#  {'0jhYMcAqY9LkMCAYNXKtNK': ['asap', 'rocky']},
#  {'0jI3Bsw6X0UK35UlUWFJX6': ['dj', 'dow', 'jones']},
#  {'0Jic1enFHt5xG7E1nHdeYn': ['lil', 'wayne']},
#  {'0JIcWmxwEpv740agHLbVB5': ['oliver', 'heldens']},
#  {'0JiEGVMAF8wzdnmXVNxELS': ['squeeze']},
#  {'0JITWDB1tVUH2VUXmVtYpL': ['droeloe']},
#  {'0JiVRyTJcJnmlwCZ854K4p': ['alan', 'walker']},
#  {'0JK5mu3OhQ17kDnfaENqze': ['gamma', 'skies']},
#  {'0jkrxTzWniCbQ6MB5n64BK': ['a', 'r', 'i', 'z', 'o', 'n', 'a']},
#  {'0JKY13K1Io2aqXJb96UyzX': ['halestorm']},
#  {'0Jl85WX8qBm0Ay9MrwUS1d': ['tonyi', 'tonii', 'tonéi']},
#  {'0jlpHhGUFn4aAWLsRRnwep': ['sam', 'feldt']},
#  {'0JmO3EBtl9qhnLkzr4FiP0': ['kali', 'uchis']},
#  {'0jmTp8jaCOm78zrdzdvmaq': ['ed', 'sheeran']},
#  {'0JmWPb3v8yq0JJODZbny83': ['a', 'tribe', 'called', 'quest']},
#  {'0JoaFxLgrqbWutREzcZBzS': ['drake']},
#  {'0JP9xo3adEtGSdUEISiszL': ['xxxtentacion']},
#  {'0jPibF4bsrW5kLxEWYoxM7': ['scott', 'walker']},
#  {'0jPU39bL0SrCmYc1RwbFkX': ['cash', 'cash']},
#  {'0JQ5MbyriK6ruD3t6RZ7ix': ['tones', 'and', 'i']},
#  {'0jqBo5RYn008f4ZY8kPewW': ['logic']},
#  {'0jqK7sGTLsHPkQrrcrGuKD': ['sum', '41']},
#  {'0jQvPp3hJlJQd9tz2EkH6b': ['james', 'blake']},
#  {'0jr6tT2vc4cIFPHb6wufG3': ['romeo', 'santos']},
#  {'0jrDmug9eevza5OnEarhgA': ['verses']},
#  {'0KE8xLEPrhrvc02uW1JMhv': ['vacation', 'manor']},
#  {'0kF0fz89HNJ1afzJ1IE1rP': ['madison', 'beer']},
#  {'0kFM6t9htbB53Dg8frGDGh': ['lita', 'ford']},
#  {'0kfp6rRddGkoyAhosSeZLS': ['aitch']},
#  {'0kHEr6iF9m7mrkTjv9pbZ6': ['ghostemane']},
#  {'0KHHrBbdvuJ6knLxj7dqkw': ['lsg']},
#  {'0KhSyTLxO3JsWHCA1zmgXh': ['lou', 'rawls']},
#  {'0khWxmAK6bqjIBygLX2XOD': ['fg', 'famous']},
#  {'0KhXVmAN4sqeEgsqRd39f2': ['faith', 'evans']},
#  {'0kHyKhJMukHEPfeh8s7rdM': ['kygo']},
#  {'0KiKfllNTmhImvXVIHqR0z': ['logic']},
#  {'0kJhWsLsNECbtcPhFnWx8J': ['inna']},
#  {'0Kk7JmX3BTE5XCaLI4mzAj': ['kota', 'the', 'friend']},
#  {'0Kk8NWt2aj8OXeYONMzxrk': ['noah', 'cyrus']},
#  {'0Kk9ucpKYg4LR8bZ3Ym5Aj': ['deep', 'purple']},
#  {'0kKJa4YVYjAclqRO7J99xK': ['topic']},
#  {'0KKkJNfGyhkQ5aFogxQAPU': ['bruno', 'mars']},
#  {'0KkrT0y1iht0tqgh9vrGd3': ['eminem']},
#  {'0KLTAGe0gzsG3UevFT6DMr': ['american', 'sin']},
#  {'0KMGxYKeUzK9wc5DZCt3HT': ['chicago']},
#  {'0kN4JHgF4LNPAPxEU3GdoX': ['thin', 'lizzy']},
#  {'0knqVSsgD7C8yu5yNmQFbA': ['damien', 'rice']},
#  {'0kntLHZ5xlkNLN6CWPetOK': ['g', 'unit']},
#  {'0KnzZd9FaVOKtOkzSvOivN': ['cazzette']},
#  {'0Ko737UNjXO17LK4Urdlwo': ['creedence', 'clearwater', 'revival']},
#  {'0KOMzOpAeg3CNrs7UceEpO': ['halsey']},
#  {'0kPeymTUiaidv48eRrMISu': ['kim', 'carnes']},
#  {'0KpfYajJVVGgQ32Dby7e9i': ['train']},
#  {'0kPIrtp3youhat1nkmPACX': ['hamzaa']},
#  {'0KPiSFlz5OUCgw7nwvhYWe': ['metro', 'boomin']},
#  {'0kPWjVyvas9lc4oXakOiBj': ['discovery']},
#  {'0kq0Y8usfSocdx1EumUklz': ['the', 'aces']},
#  {'0kqPVx9K9kEpaCMrGOpSBa': ['arizona', 'zervas']},
#  {'0KQx6HOpJueiSkztcS0r7D': ['alicia', 'keys']},
#  {'0KRKqIJPX6LT9v1ZQGbfn7': ['ghostemane']},
#  {'0KsB4TwgATg88aXCMBoO3Y': ['jax', 'jones']},
#  {'0KsWvegLnQmb6SXbQ32FAi': ['bruce', 'springsteen']},
#  {'0KT6DLAELYSbgfUemzwGPX': ['dj', 'sammy']},
#  {'0KtJ0y5Q2xS9UAjucbkcH2': ['the', 'cranberries']},
#  {'0ktUOmqwFOpdPqqGMnmHqm': ['great', 'good', 'fine', 'ok']},
#  {'0KTvHwi5cDdZh86cpZztfu': ['loyle', 'carner']},
#  {'0ku8dvIJXFh1k2zzyNQ05a': ['blake', 'anthony']},
#  {'0KUJ1RLzab3hAB1ttlnSga': ['jodeci']},
#  {'0kUMtZVaYb7EETkBdrEXXA': ['katy', 'perry']},
#  {'0Kvb0cKIssQg1t7c5KCw0k': ['olly', 'james']},
#  {'0kVebH9mitbhW6nuiInDuM': ['erykah', 'badu']},
#  {'0KW2JqqbzkzlebDjXI62OB': ['alec', 'benjamin']},
#  {'0kwBATkVUAG7JRMEosNUUs': ['lucy', 'dacus']},
#  {'0KxJEnQCG2hiHDTRcD70Sp': ['ummet', 'ozcan']},
#  {'0kXvGrU1xtobBAkQ1sf2uQ': ['sean', 'price']},
#  {'0Ky98GMSlZQdctbAhU3I0Z': ['rex', 'williams']},
#  {'0kYIsBXBR8bg8JN6xuqIDK': ['rainbow']},
#  {'0kymzJsB4BWaqq1DhOrM8a': ['rick', 'ross']},
#  {'0KyzXQhY2yzcb1FYCHkZc2': ['daniel', 'caesar']},
#  {'0Kz9aGVgFvndWkcaiylIt5': ['sza']},
#  {'0KzhyaVtr2v4J9GVdMgCk0': ['darkoo']},
#  ...]

# %% [markdown]
# # IR Modelling

# %% [markdown]
# ## **[Non Boolean Model for lyrics]**
# ---

# %%
from gensim.models import Word2Vec
import multiprocessing
from time import time
print(multiprocessing.cpu_count())
# Out:
# 2

# %% [markdown]
# ### Import an existing model or train a new one

# %%
try:
  w2v_model = Word2Vec.load('spotify_songs_en.model')
  print('Existing model detected')
except (FileNotFoundError):
  w2v_model = Word2Vec(min_count=1, window=10, size=300, workers=2, sg=1) 
  t = time()
  w2v_model.build_vocab(tok_lyric)
  print('Time elapsed: {} mins'.format(round((time() - t) / 60, 2)))
  t = time()
  w2v_model.train(tok_lyric, total_examples=w2v_model.corpus_count, epochs=10, report_delay=1)
  w2v_model.save('spotify_songs_en.model')
  print('Time elapsed: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Time elapsed: 0.17 mins
# Time elapsed: 10.55 mins

# %% [markdown]
# ### Word Embeddings for lyric

# %%
# Get the embeddings for lyrics
def get_embeddings(tokens):
  tok_val = []
  if len(tokens) < 1:
    return np.zeros(300)
  for tok in tokens:
    if tok in w2v_model.wv.vocab:
      tok_val.append(w2v_model.wv.word_vec(tok))
    else:
      tok_val.append(np.random.rand(300))
  return np.mean(tok_val, axis=0)

# %% [markdown]
# ### Finding song based on lyrics

# %%
from sklearn.metrics.pairwise import cosine_similarity

def preprocess_input(q):
  query = q.lower()
  q_tok = nltk.tokenize.word_tokenize(query)
  q_tok = pd.Series(q_tok).apply(lambda x:expand_contractions(x))
  q_clean = []
  for i in q_tok:
    if str.isalnum(i):
      q_clean.append(i)
  
  return q_clean

def find_lyrics(lyric, doc=None):
  # Get embeddings for input
  q_vec = preprocess_input(lyric)
  q_vec = get_embeddings(q_vec)

  # Get lyric|embed
  embed_lyric = sorted.copy()
  embed = []
  for i in tok_lyric:
    embed_val = get_embeddings(i)
    embed.append(embed_val)
  embed_lyric['embed_val'] = embed
  
  # Get Cosine Similarity
  sim = []
  for i in embed_lyric['embed_val']:
    similar = cosine_similarity(q_vec.reshape(1,-1), i.reshape(1, -1))
    sim.append(similar)

  embed_lyric['similarity'] = sim 

  if doc is not None:
    new_doc = pd.DataFrame(columns=doc.columns)
    for i in doc['track_id']:
      ranked_el = embed_lyric.query("track_id == '{}'".format(str(i)))
      new_doc = new_doc.append(ranked_el)
      
    new_doc.sort_values(by='similarity', ascending=False, inplace=True)
    return new_doc.head(10).reset_index(drop=True)

  embed_lyric.sort_values(by='similarity',ascending=False, inplace=True)


  top_songs = embed_lyric.head(10).reset_index(drop=True)
  top_songs.sort_values(by='track_popularity', ascending=False, inplace=True)
  return top_songs.head(10).reset_index(drop=True)

# %%
find_lyrics("hey, soul sister hey mister mister stereo radio the way you move ain't fair you know ")
# Out:
#                  track_id  ...      similarity
# 0  4HlFJV71xXKIGcU3kRyttv  ...  [[0.80473423]]
# 1  1gzIbdFnGJ226LTl0Cn2SX  ...  [[0.76938564]]
# 2  57trQKFZdJxHia4sMJioWk  ...  [[0.77208793]]
# 3  4lYxJPxy3jMEADaFhtcWRV  ...  [[0.76641995]]
# 4  6LoSKNsYkRQbyuiReooMjG  ...  [[0.77208805]]
# 5  27FnDAhPtmDJkY1GAbYv6B  ...   [[0.7774255]]
# 6  0KpfYajJVVGgQ32Dby7e9i  ...   [[0.8047341]]
# 7  3u18DwDsN8r88M3Tf0McAc  ...    [[0.883813]]
# 8  4zmx3vEPgRPjRT2CszUsZo  ...  [[0.76938564]]
# 9  5aJVMQMvdAYYkdMjNnPXLo  ...  [[0.82245386]]
#
# [10 rows x 9 columns]

# %% [markdown]
# ## **[Boolean Model for artists]**
# ---

# %% [markdown]
# ### Checking artist name's mispelling

# %%
'''
Spell Checker using norvig spell checker for artist name, some problems:
Its accuracy is worrying
'''
from spellchecker import SpellChecker

def build_frequency_list_artist():
  freq = {}
  for list_a in tok_artist:
      for key,values in list_a.items():
        for value in values:
          if value not in freq.keys():
            freq[value] = 1
          else :
            freq[value] += 1

  with open('freq_list_artis.txt','w') as file:
    for key,values in freq.items():
      file.write('{} {}\n'.format(key, values))
build_frequency_list_artist()

def spell_check_artist(kalimat):
  # turn off loading a built language dictionary
  spell = SpellChecker(language=None)
  spell.word_frequency.load_text_file('freq_list_artis.txt')

  # find those words that may be misspelled
  result = []
  for word in kalimat:
    misspelled = spell.unknown([word])
    if misspelled:
      for mis_words in misspelled:
        result.append(spell.correction(mis_words))
    else:
      result.append(word)

  separator = ' '
  result = separator.join(result)
  return result

spell_check_artist(['ed', 'sheerann'])
# Out:
# 'ed sheeran'

# %% [markdown]
# ### Indexing artists' name

# %%
def create_index(token):
  hasil = {}
  for docs in token:
    i = list(docs.keys())[0]
    for j,word in enumerate(docs[i]):
      if word in hasil.keys():
        if i not in hasil[word].keys():
          hasil[word][i] = [j]  
        else:
          hasil[word][i].append(j)
      else:
        hasil[word] = {i:[j]}
  return hasil

# %%
index_artist = create_index(tok_artist)
index_artist
# Out:
# {'steady': {'004s3t0ONYlzxII9PLgU6z': [0]},
#  'rollin': {'004s3t0ONYlzxII9PLgU6z': [1]},
#  'bell': {'00chLpzhgVjxs1zKC9UScL': [0],
#   '06yHcjr58IKJnfEK7ko3sD': [0],
#   '0RnDu3eYJqbFKz6MHv2ajd': [0],
#   '0dDifktDnbzmGwliFzI0Ld': [0],
#   '15dAoYrYVbGB7PiSE45j1Y': [0],
#   '1TsVEyryDtlexOZFXyVYxy': [0],
#   '1oNHw7yf4uvsUQeTaT2Dz7': [0],
#   '231mi5BkHyJHxQre25S6oS': [0],
#   '2donM8sTsqYtRpSAwRdPJQ': [0],
#   '3RB1O5rR8artbci5fuNK1C': [0],
#   '3VzVTs2qNdmNrCI1S9iixK': [0],
#   '3an1aoJKoBXJKoIfdDbVwf': [0],
#   '5tKenaJVfb2YP6imRnDDrN': [0],
#   '6dxOG7bXlN9wK9LXw59KWF': [1],
#   '6m59VvDUi0UQsB2eZ9wVbH': [0],
#   '70EYRjEmK12XiCX9E98upr': [0]},
#  'biv': {'00chLpzhgVjxs1zKC9UScL': [1],
#   '06yHcjr58IKJnfEK7ko3sD': [1],
#   '0RnDu3eYJqbFKz6MHv2ajd': [1],
#   '0dDifktDnbzmGwliFzI0Ld': [1],
#   '15dAoYrYVbGB7PiSE45j1Y': [1],
#   '1TsVEyryDtlexOZFXyVYxy': [1],
#   '1oNHw7yf4uvsUQeTaT2Dz7': [1],
#   '231mi5BkHyJHxQre25S6oS': [1],
#   '2donM8sTsqYtRpSAwRdPJQ': [1],
#   '3RB1O5rR8artbci5fuNK1C': [1],
#   '3VzVTs2qNdmNrCI1S9iixK': [1],
#   '3an1aoJKoBXJKoIfdDbVwf': [1],
#   '5tKenaJVfb2YP6imRnDDrN': [1],
#   '6m59VvDUi0UQsB2eZ9wVbH': [1],
#   '70EYRjEmK12XiCX9E98upr': [1]},
#  'devoe': {'00chLpzhgVjxs1zKC9UScL': [2],
#   '06yHcjr58IKJnfEK7ko3sD': [2],
#   '0RnDu3eYJqbFKz6MHv2ajd': [2],
#   '0dDifktDnbzmGwliFzI0Ld': [2],
#   '15dAoYrYVbGB7PiSE45j1Y': [2],
#   '1TsVEyryDtlexOZFXyVYxy': [2],
#   '1oNHw7yf4uvsUQeTaT2Dz7': [2],
#   '231mi5BkHyJHxQre25S6oS': [2],
#   '2donM8sTsqYtRpSAwRdPJQ': [2],
#   '3RB1O5rR8artbci5fuNK1C': [2],
#   '3VzVTs2qNdmNrCI1S9iixK': [2],
#   '3an1aoJKoBXJKoIfdDbVwf': [2],
#   '5tKenaJVfb2YP6imRnDDrN': [2],
#   '6m59VvDUi0UQsB2eZ9wVbH': [2],
#   '70EYRjEmK12XiCX9E98upr': [2]},
#  'ceelo': {'00cqd6ZsSkLZqGMlQCR0Zo': [0], '3ydfhgIZIc2j39NLIhpJpq': [0]},
#  'green': {'00cqd6ZsSkLZqGMlQCR0Zo': [1],
#   '0toJeVTW2hHX9qYVmdOpBs': [1],
#   '1Dr1fXbc2IxaK1Mu8P8Khz': [0],
#   '1hwJKpe0BPUsq6UUrwBWTw': [0],
#   '3I8Ri6tLa4QA11MMdZywtM': [0],
#   '3ZffCQKLFLUvYM59XKLbVm': [0],
#   '3ydfhgIZIc2j39NLIhpJpq': [1],
#   '4VgEM12OeaN3GyBV487Me7': [0],
#   '5GorCbAP4aL0EJ16frG2hd': [0],
#   '64yrDBpcdwEdNY9loyEGbX': [0],
#   '6L89mwZXSOwYl76YXfX13s': [0],
#   '6nTiIhLmQ3FWhvrGafw2zj': [0]},
#  'kard': {'00emjlCv9azBN0fzuuyLqy': [0],
#   '2U6RSyXFnDVNYoD9iUgi09': [0],
#   '5bvGVgllIIJwcy2YstlGU1': [0]},
#  'james': {'00f9VGHfQhAHMCQ2bSjg3D': [0],
#   '0CmIALzGn4vHIHJG4n3Q4z': [1],
#   '0EDfF4djtCu48KZtSHx5jW': [1],
#   '0IMQFfmMikvJge5bweNVxe': [1],
#   '0IeFn6mSeSiXvB2dGgpdEI': [1],
#   '0JumfyG7GUshFjxouEXwhw': [0],
#   '0Kvb0cKIssQg1t7c5KCw0k': [1],
#   '0VhgEqMTNZwYL1ARDLLNCX': [0],
#   '0gT00heO9IfOUFwdkcIOVH': [1],
#   '0iHO8dmXhSYCgfow7ckt9W': [0],
#   '0jQvPp3hJlJQd9tz2EkH6b': [0],
#   '0nyrltZrQGAJMBZc1bYvuQ': [0],
#   '0vg4WnUWvze6pBOJDTq99k': [0],
#   '116uqdetf6JQtnnlYsyBfa': [1],
#   '133G9W0ZHEi5TfZTWTYXGP': [1],
#   '13v3siPyvy5TTEZYmGPPse': [1],
#   '13yEuYLJYxPCLJR0KNOqpk': [0],
#   '15xWRPHQMeqgdkGzInx3PY': [0],
#   '1F7ZElvJAvWKQ7UaPXg9cF': [0],
#   '1KZyVnyptQcPzkx7ELCnZC': [0],
#   '1Pw5C4N6Fn5E4mGCxmbbVa': [0],
#   '1Q34tAtTWI6RdW1qzFQiPb': [0],
#   '1SBfo3rRQiP9RnBvgtk0hF': [1],
#   '1bQhZOoXYqjXs7u7rFXo0h': [0],
#   '1nd9moIZkGvWoHtReFqkRY': [1],
#   '1p80XDFkNwDaA87sh2C2Xn': [0],
#   '1umJyGPzSaIzgh0Na4lE1E': [2],
#   '1uru26I2JKd2mQZt0MDCUe': [0],
#   '1zVBU0PAj7ZUVmVfG2pgQG': [0],
#   '27F9FlipD657qYRQT3qxFm': [0],
#   '2BVzcBHL8C2Cu44AfAkfLJ': [0],
#   '2CPLHpu6yj94dpuQ7QDDpu': [0],
#   '2CdS3DRqWR5LAhy4hM5X9W': [0],
#   '2Dpe4Wnm8lQ07nk2SfzvEz': [0],
#   '2HuKPBTjdwDz4AgyScuMDe': [1],
#   '2IqjKEBiz0CdLKdkXhxw84': [0],
#   '2OkU57LVQoynnVyLE1LrPN': [1],
#   '2RwFdFIN9JAyVUzevwkzez': [0],
#   '2UrAeVF1jqprpG9mWisUH1': [1],
#   '2XUwZ5CObNFeMfU4PHkWEB': [0],
#   '2YX0K9fzoyqWpT5sgyzVXS': [0],
#   '2gWQa5iZr3gHkJy8BOuQJW': [1],
#   '3bWGaqVeYKMlLss40mPgNn': [0],
#   '3C0uXzWyIg8d6WBrBviGKc': [0],
#   '3ccAZx3wLZDVB2Nq6rikf9': [0],
#   '3Cgv8rC4pdfRTmmQEpRjkO': [0],
#   '3clIHVzJ9J2rvvrFUKLICo': [0],
#   '3ctoHckjyd13eBi2IDw2Ip': [0],
#   '3D1Xnj2Q7oh7Vz3RH9fDvC': [0],
#   '3d4z8zsN0zlYHPb8EeADxZ': [3],
#   '3Dgm3Eaw7mBjYrGxdZxfjl': [0],
#   '3dhjNA0jGA8vHBQ1VdD6vV': [0],
#   '3dqGLyXoP2Bo32eU6Rd8SQ': [0],
#   '3Dt75NjLThmoBTp5wQC7g7': [0],
#   '3EAFamlgsYPA3HijLUPszI': [0],
#   '3EXrtClWmgsM7dw75Mw2M1': [0],
#   '3EYOJ48Et32uATr9ZmLnAo': [0],
#   '3FmAUR4SPWa3P1KyDf21Fu': [0],
#   '3FUS56gKr9mVBmzvlnodlh': [2],
#   '3FWPoYBDserKdzcattMFGa': [0],
#   '3fxETTPvwxkkpq3Ax2ZbcN': [3],
#   '3g1iyXOgxuPm9zkzqpDOeT': [0],
#   '3GbgDxpsb0uydqD8haxjwn': [0],
#   '3glpIWHHvA0MgWnzB0mXqX': [0],
#   '3Gmt6Ki1tySCY6sXvmnR1Z': [0],
#   '3gNNXc7GUgKRPR15W77eDR': [3],
#   '3gqVjhFpPMjbZBLNJ7nhj3': [0],
#   '3gVaOBlP4CaRqfUttZ4Avd': [1],
#   '3GXo1eWlT2flv4x01l5OTu': [0],
#   '3GzZfni9NCD54x1prgpIYl': [0],
#   '3h2pnVxdlwh4NWjRkSiMac': [0],
#   '3h9uL1GB5GU0TdNPrFHluJ': [0],
#   '3HFdPsHeAtmIrCz5fOYnp4': [0],
#   '3hyi4CYvZ3K6EqAI2ja7pl': [0],
#   '3iT4vWUWxqsn4hFTkEaJCi': [0],
#   '3J58Ccc5iTbCRnYx2xjo6d': [0],
#   '3JAqEYLvkXUECDgWgY3SBv': [0],
#   '3JbE6e17yvNdPggjPDrCyO': [0],
#   '3JERoo6pokCgQ81z79Jpmo': [1],
#   '3JEzGRDUsozrehZTq3dKE8': [0],
#   '3JfkNCiXjHEVkbFfCQ417E': [0],
#   '3jGnPHFrBCTdtEXbfweXgH': [0],
#   '3jNyatJv1JxuIlwKoYlo7Y': [0],
#   '3K0SJUQNbOkUprTFcwwAKN': [2],
#   '3k9i7UzeSUYWIfUZFeFDUd': [2],
#   '3KapR70eIR6Zm3kJfG4oB3': [1],
#   '3KfbEIOC7YIv90FIfNSZpo': [0],
#   '3KiexfmhxHvG5IgAElmTkd': [0],
#   '3L7RtEcu1Hw3OXrpnthngx': [0],
#   '3LewMbGqmR4IYtifSNxbGz': [0],
#   '3LQPTJEqOfljGBxmpgUnoC': [0],
#   '3lWHWGrRrVrEoYwolWZ38x': [0],
#   '3lX49Bqy21Y5HneUJ7p55G': [0],
#   '3mayeyaPg5DQGBa78LJM59': [0],
#   '3mlMpmY8oZIBFc39D9zLbh': [0],
#   '3mTEYjm3kIm4YzJ5zxJZjs': [0],
#   '3N6V8ppRNlbAhqwFzlGgHP': [0],
#   '3NPvE7siGFFFB1lwTBwF3F': [0],
#   '3Nseorafz0uxtBrzFMKEsy': [0],
#   '3NWTRZ0A8xKlBP1qgNftql': [0],
#   '3NYCaxkggl0Hh8vQptSUvV': [3],
#   '3O4tAyCKMYy1DIosXy1wAv': [1],
#   '3O4TPMOgChXOerSdB5WENH': [0],
#   '3Oa8vnNXStoOHLbJwwMEDP': [2],
#   '3oDFtOhcN08qeDPAK6MEQG': [0],
#   '3odPjdX1SjxxjIr0EZjEht': [0],
#   '3OkORslI7AcejLNnMVM92o': [0],
#   '3okPiJwW5nCLpug12sCL4p': [0],
#   '3OS4XXm4S42pnESQmtN9MG': [0],
#   '3PFaFVWq5wucLu6s4baj9D': [0],
#   '3pGnvyd0UBaFKF9PYM2ULM': [0],
#   '3pWcj8hxj3fsb9TDAcMpEl': [0],
#   '3pyoAvbBO4kDKkh999Miyj': [0],
#   '3qel23hQWhHT3qGewBQ0pE': [0],
#   '3QfJhbiVGJucxyUbOFiaLY': [0],
#   '3qI94hINNNeb4S7xQi18lS': [0],
#   '3qiyyUfYe7CRYLucrPmulD': [0],
#   '3QNo5oDTOSI23CDDpDUE9Q': [3],
#   '3RciEQxS7PxtLqMs7OwRsU': [0],
#   '3rdFEtI9fiqQYBVyIaOBh9': [0],
#   '3rez7t0KrJuhx6HNAyFYWH': [0],
#   '3RZMzCvYsmJ0u2ioKTOsmJ': [0],
#   '3rzYUfyzdZW96cHXnGn1xI': [0],
#   '3st9lesONapXvHLIRTbQCz': [3],
#   '3SUusuA9jH1v6PVwtYMbdv': [0],
#   '3SVXhtxFCNJnA4MkWF7sJp': [0],
#   '3SwhPTNNU5hpF33bbCsji6': [1],
#   '3T2ibiKCatzkbTnn3hOyyQ': [0],
#   '3T3aWHBbX85hqRPsd8vhJB': [0],
#   '3TcL0dyCMyr0kyTTc4NLgI': [3],
#   '3tcmqEQe8CUmktxtlZPow5': [0],
#   '3TS25nchaYIPb2Y2fw6cbb': [2],
#   '3twNvmDtFQtAd5gMKedhLD': [0],
#   '3tWp93Y61r4j6ASXbJVUL9': [0],
#   '3UDmHZcBTQp8Iu8droNtUl': [0],
#   '3UEfOvhtrnpw57gDbSixri': [0],
#   '3ufbsUF0fpOjHmBOGjYSQ0': [0],
#   '3UhwS81S9L7i2byZCrhSAv': [2],
#   '3uJsg8xIH7OpWHxuJaMLJX': [0],
#   '3UsbGR71AjcBYOWoUlfTdm': [0],
#   '3vFj4xuQTXHOuo6L0qGafv': [0],
#   '3VIJBrMpvimHEw5wtPh2wB': [0],
#   '3vv9phIu6Y1vX3jcqaGz5Z': [0],
#   '3vwmTGh2zgxxoJzvcvJfhm': [0],
#   '3vy2QK19RCnS4Egaq9fGhy': [3],
#   '3WIg3fd3W8I5HU8g3Y6P0k': [3],
#   '3x1v32I3SZNvC7q7bDhcGm': [0],
#   '3x2bXiU0o4WbsPkawXlfDA': [0],
#   '3XC7Jd6SfrQYKZJ6inyRHK': [0],
#   '3XGBFBUEalGmIDcjvu4nrj': [0],
#   '3xRzUblYGZhVs52fMjii7R': [0],
#   '3Xzog9enTvbsc0G7G9M58D': [1],
#   '3Y4rUyw7XBCK6hGHCOt6rp': [0],
#   '3Y8Ff1nH44jFywAtpgmleZ': [0],
#   '3YQ96qkxiEwTLwgu2Izcmq': [1],
#   '3yZQk5PC52CCmT4ZaTIKvv': [2],
#   '3zlXiQYeJJh3BN4up7zSFb': [0],
#   '3ZxfehzRtB3oJcBuxWXFZQ': [0],
#   '407ltk0BtcZI8kgu0HH4Yj': [3],
#   '408auwR6AlpKxDyJVpwdyC': [1],
#   '40c498Ic7gnr1znNRZiPPV': [0],
#   '40gDRdKSnvuYSESfYOTLyH': [0],
#   '41aOyMZXFwvwRpugIlNCGF': [0],
#   '41th2RVnBYzhP4EQse7jAC': [0],
#   '41U86awdgg7CKQUA4twR68': [0],
#   '41ZcBumDBhCqSCWTH4KVdq': [0],
#   '423hwXFgoN8RYmqLoLuVvY': [3],
#   '42e1QfTyPYWuoddr0ghc0i': [0],
#   '430qNtapCS3Ue1yoSql1oV': [1],
#   '439sdo18d2vVo7crU9KWp1': [1],
#   '43jBqV3j3Xi1g6wO0bhIMd': [1],
#   '43z6scIZU2QcEieMQFAJRG': [2],
#   '447yWcDPg1ddgcHBLGpJC0': [1],
#   '44qXe4KIx8bu9eLtTV1BB8': [0],
#   '45ipml9tB0PVrLFAJegcWE': [0],
#   '45s88Xopo6KvHc0PQ05aGg': [0],
#   '463j73X5yU9FdnoI0XaU9k': [0],
#   '46Kcradxrva9Dny4lHU1b3': [2],
#   '46X8c9qJzpBLYcos3OX0CE': [0],
#   '47euMdzPz6bdj7EKPy369S': [0],
#   '47PfqyXzLIKQp37yJNITrs': [1],
#   '47R9wmldBrYFtkNRjVSPZq': [0],
#   '47wPvRG8FEwbZP22UBgTQr': [0],
#   '48n92l7OnLEURhalUBtsl7': [0],
#   '49rpdsNYJirTTf6p6mMvag': [0],
#   '49TrrciRvL6X0VSP4Q3HhA': [0],
#   '49wHCjiu34kM3VRgumQ1tJ': [2],
#   '4A1Egs5QQCHGClMB53HLGW': [2],
#   '4ai7fpzyfaGBlMX5kZGmYu': [1],
#   '4ajF5UznaEpfHFXv64AQ7T': [1],
#   '4alHo6RGd0D3OUbTPExTHN': [0],
#   '4azFYRLO5CCUXl7DSpluma': [0],
#   '4B3NahKokb7lLkvaLFZFzn': [0],
#   '4bca5vEisb9ImSQ4PlQh2T': [0],
#   '4BdGO1CaObRD4La9l5Zanz': [1],
#   '4bEcoz1OcfMgUbp2ft8ieQ': [1],
#   '4bEqHXsdbYBOghD2DUYROa': [0],
#   '4bID7c3Y5FmaIOEhVsE8xi': [0],
#   '4BiiOzZCrXEzHRLYcYFiD5': [0],
#   '4bqTcIQAj0aqqyS5LzMVPx': [0],
#   '4buDeg67vos7KP1yHrS9wl': [3],
#   '4BVE5tIIpYabZcYCbephNW': [0],
#   '4bWapK9CYlRbK1B5Sz6ee0': [0],
#   '4yT3UMHdi1p0xkmLuwOu6f': [0],
#   '4zEvxRDaKDoFlHxK7Hy0wg': [0],
#   '4zvHX7fRYpva5QO4cV27yl': [0],
#   '4zzi2eD2cEPpQ3a307mPPj': [0],
#   '50RJdoxw8iajGNtHQe6QeS': [0],
#   '51MgEk3WbfGP2qbixAVAlZ': [0],
#   '52dm9op3rbfAkc1LGXgipW': [0],
#   '52MmMUuyjO64Y1EiF7Y8KH': [0],
#   '537yo062QIz16oQOgxmul3': [0],
#   '53xSIYBcFnltfPf6ZyQ4je': [0],
#   '55oYSMee1hEvnQrQBEELnO': [1],
#   '56KqaFSGTb7ifpt16t5Y1N': [0],
#   '57BqPLE4mvQEBh53JWxgcI': [0],
#   '57F04Uot63WsXQC3sE5TLq': [0],
#   '57iDDD9N9tTWe75x6qhStw': [0],
#   '57vxBYXtHMk6H1aD29V7PU': [0],
#   '57Xjny5yNzAcsxnusKmAfA': [0],
#   '58brvcrp3VivwIxRR8gT6Y': [0],
#   '58fdemGY4fTjdB37nTPGRk': [0],
#   '58HpsDKeYoLtNhXFQyQmz5': [0],
#   '59kTVUKhpcFw9zMLPSbFvH': [2],
#   '59WN2psjkt1tyaxjspN8fp': [2],
#   '59XNy4523UcEvQfYM8fdQB': [0],
#   '5aAx2yezTd8zXrkmtKl66Z': [0],
#   '5agxCIWiABK6l4ltmCAHoH': [0],
#   '5alKIB3JaJ4N1RwbsTz9jO': [0],
#   '5aQfUmnxj8x1zYc37Wit9w': [0],
#   '5awYzFyHCxgvgtiE1H2WvK': [0],
#   '5AzpZ5ADn1AFPxcEBd2Ugf': [3],
#   '5bQduNI1lNfkNbDCKhBNX6': [0],
#   '5brMyscUnQg14hMriS91ks': [0],
#   '5bSASu4W0HJx6CuG8rbRcA': [0],
#   '5C0LFQARavkPpn7JgA4sLk': [0],
#   '5c5a2Ptu8eyIpljhQHjIqk': [1],
#   '5CPqOpKSk0QcJ3dGdaWcRB': [0],
#   '5d7o3xXERxQGzqk4oMBeiZ': [0],
#   '5DHAUZAwwVxcaUnPeSth5I': [0],
#   '5dikapPlQPrsT3xUsUjj0N': [0],
#   '5dJw4bL9BziBStitvelyAS': [0],
#   '5DkwgbwtvFzj7ITGkaSGxS': [0],
#   '5dnvWWkwwFJoDDc0QoSbvf': [3],
#   '5dRQUolXAVX3BbCiIxmSsf': [0],
#   '5DuTNKFEjJIySAyJH1yNDU': [3],
#   '5eB7w8UZJKjL5XmnC6Pctg': [2],
#   '5EcvzboYmDIfXo9gPplsSB': [0],
#   '5EdYlCWou17k0N1PADLKfO': [0],
#   '5eYwDBLucWfWI5KsV7oYX2': [3],
#   '5FGBOYI8mj9chVhWlNOVXK': [3],
#   '5FMlUJ6wd2aN0lkdlRrEtH': [0],
#   '5fSVerSB7TpXkUF9BxTUcP': [0],
#   '5ft1GmMZA4uNX7afvQfDLn': [0],
#   '5G1sTBGbZT5o4PNRc75RKI': [0],
#   '5GjisoOfsN8qagrax01T4y': [0],
#   '5GKVcvTgnFYtfh25qKQtRg': [0],
#   '5GuLKwgYs2odLi5LwK6oKA': [0],
#   '5GXAXm5YOmYT0kL5jHvYBt': [0],
#   '5GyPVseTXBFhXEOXYaTeXh': [0],
#   '5HCMxtjQaeLrNQOT5qRksq': [0],
#   '5hVghJ4KaYES3BFUATCYn0': [1],
#   '5hWdgGVcfTeLPAiHM6EZG9': [3],
#   '5iOc8d1LkUdQ9AbDjSBrVQ': [3],
#   '5IpKZbfJNefqY6nMejBHjr': [3],
#   '5JAWf4omEzwccQNE8Y6kvn': [0],
#   '5jzma6gCzYtKB1DbEwFZKH': [0],
#   '5KMPp9asnxJwvaBuSZ5Nsn': [0],
#   '5KQDGl3vAkNGyfvSbaW89E': [0],
#   '5KRRcT67VNIZUygEbMoIC1': [0],
#   '5KY7zgFeH2GWoL1zP9mME6': [3],
#   '5kz9GDBTX846OXwqWoyKzF': [0],
#   '5l3iCMN9GLxofclApZXcmR': [0],
#   '5lN1EH25gdiqT1SFALMAq1': [0],
#   '5LPGZnsy07YNxeuTI1X3RT': [0],
#   '5lrrbifCju6fWX4n1GPRuY': [0],
#   '5lXG3SLCMVk7dJzp1YeMni': [0],
#   '5MgBUUjbkQ27Kd9CbeZFLo': [0],
#   '5MjAFPcmrR1DYCgZrXCN4d': [1],
#   '5Msytfzyrxcaj5mjs3M19e': [0],
#   '5MvLsT03RBp67RLoeISCdl': [0],
#   '5n0CTysih20NYdT2S0Wpe8': [1],
#   '5NK8jad728pj6YeqM5VJD4': [0],
#   '5nrmGFJ87crVoJF5xdRqwn': [0],
#   '5nYZAg64b6sEpukTSuuSUZ': [0],
#   '5O3nMjk8xL7n4TIh0tym4i': [2],
#   '5okFkhRbWOSDWp3c15ouMB': [0],
#   '5OPgPWsCaeZDvHudPzVftQ': [3],
#   '5oPUBUzrAnwvlmMzl1VW7Y': [0],
#   '5OWokvF4QOqMDQ8ByQsm6V': [0],
#   '5Pdd4QCr0rREXM03zBM2Eh': [0],
#   '5pFXepfAbXlLUm5vBZXXXW': [0],
#   '5PM96PMKMfD1lLX2lryUsG': [2],
#   '5PmPW1JYDmwPtamsOTgkzu': [1],
#   '5Po5YmT4RhawSeqNXx5m0o': [0],
#   '5PrHp3PRK78k18zrwgyxS9': [0],
#   '5Pshy0bOUQfOaHaz7KwPse': [2],
#   '5pvZGipNqXbamr7K8TVolA': [0],
#   '5QcQcmeXFT0ayv8sBcnMYY': [0],
#   '5QHLHBmGDW999nMelytjUA': [0],
#   '5qiDen4GXbcZixkS114QXw': [0],
#   '5QkVPG2Hf3MmAarireF6lh': [0],
#   '5QLHGv0DfpeXLNFo7SFEy1': [0],
#   '5QpaGzWp0hwB5faV8dkbAz': [0],
#   '5qXDMDeaGVoWIRAIQ7aCcd': [0],
#   '5R0v2GLujsGk37QCkGdvMQ': [0],
#   '5RApJB3xWzniVnHtQDAaCP': [0],
#   '5rbHxYjIAs4flh30UL66dO': [3],
#   '5rBOBI3INEw0u0rwNNGib5': [0],
#   '5RfhUFcQBeonzqLRhU8gvK': [0],
#   '5rgnyXr2PXFWsAnPFew077': [0],
#   '5RhxBpoCwX2vLBcSJzYa5j': [3],
#   '5RoIXwyTCdyUjpMMkk4uPd': [0],
#   '5RTeMqtMcVCOukwgiNg11H': [3],
#   '5SaXgo5XteGjNWOUGKzwfA': [0],
#   '5sCvipEhpAhVhu3K6kzm1P': [0],
#   '5sUrlBp7h4aijnw9QwntnI': [0],
#   '5sWevAyvYSRzGpIsdsRvJi': [0],
#   '5SzhkC3NGjcIq6Brs8pSj1': [2],
#   '5t3KWr8w3yGrAUEqCfizlD': [0],
#   '5tASX9SKT8vFTQpfm5UVJT': [0],
#   '5tjpOTsbVVbqWRQuymGnuy': [0],
#   '5tqZJUHEuqdN12RZVq2l9p': [0],
#   '5U1eDhGNl6uUQThJ4nBm7z': [0],
#   '5uMHnkSFTkYV764nfjoGKM': [0],
#   '5uOTvcWHsvvDQ8z1Q9K64f': [0],
#   '5UUQUFsYJyfF6YwqTnquuA': [0],
#   '5uvosCdMlFdTXhoazkTI5R': [0],
#   '5UwbnHhjnbinJH8TefuQfN': [0],
#   '5V31p6JbrGE5tfKrxzQNnM': [0],
#   '5VKU0Lh9deNkVq046FVIir': [0],
#   '5voO100jVn9PK4NUETgM8W': [0],
#   '5VrSusNzgppBYodq9jhRus': [1],
#   '5VRxcsBgrwQj4naQHU2kM6': [0],
#   '5VtqYOQrtrBoaZKMaY0HcK': [3],
#   '5WNYg3usc6H8N3MBEp4zVk': [1],
#   '5x53pbGk6sbl1BGom19QQ5': [3],
#   '5xD021bM8VbqrhCVhxRozx': [0],
#   '5xLfQuX5YAfog2JgPz0dpA': [0],
#   '5xok0LRntz8qY9ljEwPV9L': [0],
#   '5XVb0qfmmkmmsyy7j8oObk': [0],
#   '5yDL13y5giogKs2fSNf7sj': [0],
#   '5YkOuhqiQWvcTk2kvyver4': [0],
#   '5YY6Z7YnjGOPxYy8ooZmLC': [0],
#   '5YzaostcCu9Sgp5T7bFuX3': [0],
#   '5ZdzNVOmCSp5HFLk0EgvJS': [0],
#   '5zHXpOhaBlL0FrXGmIRrjO': [0],
#   '600oiqLkQIJ85HvQGIQWvO': [0],
#   '60eOMEt3WNVX1m1jmApmnX': [1],
#   '60TmG8cFPMBo7kTTFOLiAB': [3],
#   '60ubljabcQKHeMpjiypBcH': [0],
#   '60VcYHxoyOdZyFb1EaKJdN': [0],
#   '60WcXjimfbhk6T0gj1Eufg': [0],
#   '60xaS8mYBKUW4VQQ666N0T': [1],
#   '61Q9oJNd9hJQFhSDh6Qlap': [0],
#   '62GXGpd73vslqIBHq8XqOx': [0],
#   '62NQ8JoW3yfJ2WSmlnaogw': [0],
#   '632wpQN4nWLEvxUyGZxyLM': [0],
#   '63lqz49MWHGKGVoOJVVWwo': [0],
#   '63QPrB9P5VoLNztjlSep0G': [0],
#   '63xBnyUVKIupzjHno4wFs3': [3],
#   '648BMGrt98kUbLo24A4vgj': [3],
#   '64BKKgWdKdmKlQDzRfHW3C': [1],
#   '64HCsmzpvUpSTM4mNAOR5S': [0],
#   '65YX6qx31L6SOQlrSMGYeM': [3],
#   '66w1iMtSQUJz5dsqJx4QPS': [0],
#   '672N8DGGTOLCOgWe0koX5g': [0],
#   '679RG1vQ3m1liChyglObX9': [0],
#   '67SMaSkF6rOBiTkwLCMUIW': [3],
#   '67uQCds7ugUZn3TZUhc5dB': [0],
#   '68yqiuPVxrT9OySWFDwDDd': [0],
#   '69lOXkCMEPFSDwuuznGjMy': [0],
#   '6aAwVy5Hzf44HaXlG6INFO': [0],
#   '6ACiYjq5Q7e6BlhZEHz7cd': [1],
#   '6AcMShL9nO1oQHsmVhiKPn': [0],
#   '6aiap0DxIpyscSAIaPp9kk': [0],
#   '6aldtNKtl5yHkKlwXH0nIY': [1],
#   '6AXO3W0HCu1qH5LDKa77kJ': [0],
#   '6B4HHb1bgnSiNHOyub6Vqq': [0],
#   '6b9SBw4AxSJUYEetOS5Sc8': [0],
#   '6BCMCf3kh2VFe3fTU8Jv2R': [3],
#   '6BrMEbPSSj55nQhkgf6DnE': [0],
#   '6dET51TwAJPrKV5wmA5Vhr': [0],
#   '6EJMN1wW6ciSAB57yRLErU': [0],
#   '6enXeBnLnyjfweN6VWcIoh': [0],
#   '6EsBn1Md8C5YdbCzvwvZq8': [0],
#   '6EWIZKl3rQUSnvT7EI3uta': [3],
#   '6EZDbjz2X5XzgIZCtbsrXh': [2],
#   '6FaHStqRlwqJc2mxeEuFog': [0],
#   '6FEKEO3y7QFcMwoGeR0GtU': [3],
#   '6FTOdb1za7uQV5R929LFwe': [0],
#   '6gGSSrKMiV2yec1DrqGhhy': [0],
#   '6ghGfGpipODLLDyzcolTGW': [1],
#   '6gQaf0ANLks2uWl2AHhU26': [0],
#   '6GqRl2u7LIW93T8Vi5LnXU': [1],
#   '6gXsswvH6gtSkbrecXAeQN': [3],
#   '6GyDY0yE47rfk8pcuKhioh': [2],
#   '6H3kDe7CGoWYBabAeVWGiD': [0],
#   '6H4IrhaJFaoXrSuQQKfzpD': [0],
#   '6h9xi8i9zVOXk5FqGqcBNH': [0],
#   '6hNb6q0DhKIV0hwscYGVC8': [0],
#   '6hyKhlwAvLvVh0ZysHFLnq': [0],
#   '6hypt8VPJxeMXTTcRUHS86': [0],
#   '6igsoAR6Co9u7Rq3U7mlOD': [2],
#   '6ITuEsxEy2qPhqMowdDAeI': [0],
#   '6J6RWKCPN5RFKHUKEUFjxS': [3],
#   '6J7PIkhtHwmFjPLq0SyuPj': [0],
#   '6jEcFhllWB0clBHFylomJZ': [0],
#   '6JifQymydeuqrgE7KhjHAM': [0],
#   '6jljsFw0Hypb56SgaJSSSg': [0],
#   '6jWkZvd1URGktyTTwcpPpB': [0],
#   '6K6et6hTnu1IyWAZsyQlYO': [0],
#   '6KjJGpDZ4wdshirWmqBcT3': [0],
#   '6KuXb26rHuRy3ZDse1VRmx': [1],
#   '6KxWEKZT63q9ioV38MuZxZ': [0],
#   '6L3VWDPDTQkQFkqvmpAUMU': [1],
#   '6L5BZEcZmD6RBJnimzlyKr': [0],
#   '6l5XnGdX73q4zuniAQgKYC': [0],
# ...
#   '6fAADiK2jnjdm5QRI7hSYc': [0],
#   '6s0NHplywwr1IjnQpUpWJk': [0],
#   '6tvs6KCRXP8zKhMmMw3OO1': [0],
#   '76TpWFiK5YCgw1hy26DWZp': [0],
#   '7GJClzimvMSghjcrKxuf1M': [0],
#   '7KasuMXuWHA36uFtFKuHPw': [0],
#   '7ewtBCQfNha1hzKCubsufW': [0],
#   '7puxIVNdj5nsBJk43zM3bH': [0],
#   '7q0aQpiLv5tIsupcgQ3Ny4': [0],
#   '7ykaUgkdQWJLsMuOymTV2A': [0]},
#  'nause': {'0HeTpk89fOwfTBVL5d2acE': [0]},
#  'jason': {'0HFx7PLqzGxSfN59j3UHmR': [0],
#   '1DPrKU9EvePcDg7v4JLmGd': [0],
#   '1EzrEOXmMH3G43AXT1y7pA': [0],
#   '1Fg46JadAkJ9ugw7mSBUSN': [0],
#   '1j5cGcXWdHKTPQ2XgXODJI': [0],
#   '2z4pcBLQXF2BXKFvd0BuB6': [0],
#   '3S0OXQeoh0w6AY8WQVckRW': [0],
#   '4fINc8dnfcz7AdhFYVA4i7': [0],
#   '4hbGPfz03P8Nnh75mFIAoH': [0],
#   '5BoIP8Eha5hwmRVURkC2Us': [0],
#   '5Xn4IyTtW6FUGIUyWjbUHG': [0],
#   '5YHR8wBR5jXfGtP766NiAT': [0],
#   '5l3CML2OnzfNs5RfVgbcLt': [0],
#   '67T6l4q3zVjC5nZZPXByU8': [0],
#   '6ILsOdeN5cv3M0tp0ootWF': [0],
#   '6St9lR6dhV2tpCNVz7qfrS': [0],
#   '6jizk5lOUnfpaZXYMdfeC6': [0],
#   '6kex4EBAj0WHXDKZMEJaaF': [0],
#   '7oGZAicScQt96OAW4AruYy': [0],
#   '7xkQdy0cy5ymoWT7nedvLz': [0]},
#  'derulo': {'0HFx7PLqzGxSfN59j3UHmR': [1],
#   '1DPrKU9EvePcDg7v4JLmGd': [1],
#   '1Fg46JadAkJ9ugw7mSBUSN': [1],
#   '2z4pcBLQXF2BXKFvd0BuB6': [1],
#   '4fINc8dnfcz7AdhFYVA4i7': [1],
#   '5BoIP8Eha5hwmRVURkC2Us': [1],
#   '5Xn4IyTtW6FUGIUyWjbUHG': [1],
#   '5YHR8wBR5jXfGtP766NiAT': [1],
#   '5l3CML2OnzfNs5RfVgbcLt': [1],
#   '67T6l4q3zVjC5nZZPXByU8': [1],
#   '6ILsOdeN5cv3M0tp0ootWF': [1],
#   '6St9lR6dhV2tpCNVz7qfrS': [1],
#   '6jizk5lOUnfpaZXYMdfeC6': [1],
#   '6kex4EBAj0WHXDKZMEJaaF': [1],
#   '7oGZAicScQt96OAW4AruYy': [1],
#   '7xkQdy0cy5ymoWT7nedvLz': [1]},
#  'clean': {'0HgIbfeOw6dLuGmPippTlh': [0],
#   '1CSk9lJFJt4OdcvOH5iK61': [0],
#   '1t3HCpt49x27PE1uuy06md': [0],
#   '1x5sYLZiu9r5E43kMlt9f8': [0],
#   '2CqnpBHeQGfgj8FDB7zuTv': [0],
#   '2hrUO4drrO63i7FYbCLBl2': [0],
#   '2xmrfQpmS2iJExTlklLoAL': [0],
#   '3Mong1BzxMKwTZ0SbfLdcQ': [0],
#   '3NuK5xMlSlB6K2Qp16zf3h': [0],
#   '3WDIhWoRWVcaHdRwMEHkkS': [0],
#   '3s4U7OHV7gnj42VV72eSZ6': [0],
#   '5Q7h7R1D9q7gkB1FimDsCE': [0],
#   '5YncMl3WSmzvwkiIU2K8cl': [0],
#   '5knuzwU65gJK7IF5yJsuaW': [0],
#   '61dCUoMCg28qEBzrW6htYM': [0],
#   '6kPJZM97LwdG9QIsT7khp6': [0],
#   '72gv4zhNvRVdQA0eOenCal': [0]},
#  'bandit': {'0HgIbfeOw6dLuGmPippTlh': [1],
#   '1CSk9lJFJt4OdcvOH5iK61': [1],
#   '1t3HCpt49x27PE1uuy06md': [1],
#   '1x5sYLZiu9r5E43kMlt9f8': [1],
#   '2CqnpBHeQGfgj8FDB7zuTv': [1],
#   '2hrUO4drrO63i7FYbCLBl2': [1],
#   '2xmrfQpmS2iJExTlklLoAL': [1],
#   '3Mong1BzxMKwTZ0SbfLdcQ': [1],
#   '3NuK5xMlSlB6K2Qp16zf3h': [1],
#   '3WDIhWoRWVcaHdRwMEHkkS': [1],
#   '3s4U7OHV7gnj42VV72eSZ6': [1],
#   '5Q7h7R1D9q7gkB1FimDsCE': [1],
#   '5YncMl3WSmzvwkiIU2K8cl': [1],
#   '5knuzwU65gJK7IF5yJsuaW': [1],
#   '61dCUoMCg28qEBzrW6htYM': [1],
#   '6kPJZM97LwdG9QIsT7khp6': [1],
#   '72gv4zhNvRVdQA0eOenCal': [1]},
#  'shura': {'0hiFoxxMg36FoPIdmiAyfX': [0],
#   '0oInDc8Q0nc8I6mKIliCfk': [0],
#   '23OvxppBAZq6xqLrQpyytj': [0],
#   '6S00LsQDmqMtyVy1HzROR7': [0]},
#  'll': {'0UN5OvKlbg06LnZyVk48ll': [0],
#   '0hioWv2FDtVePjHFTwgrf7': [0],
#   '2YKnKXUeGERi9yCLTO2C3t': [0],
#   '2e7mHNFlXCkFdKjJ3nsK9E': [0],
#   '2hSiACXW5Nt0yUxWUsoIpU': [0],
#   '2vAbKDdqA6cEBHU9zQiA8g': [0],
#   '4F4neui0edP1ozygvFiCi7': [0],
#   '5X48562lzIHeCKKLLSIGMm': [0],
#   '6dQJI4hFolhMnZhSHxkuGc': [0],
#   '6jL1SnyXcXiKOmw4M2RnmT': [0],
#   '6tZAvhrqkVhwFgptDHz5Wr': [0],
#   '7x7kYJwduClF3I0ozJpNsZ': [0]},
#  'cool': {'0UN5OvKlbg06LnZyVk48ll': [1],
#   '0hioWv2FDtVePjHFTwgrf7': [1],
#   '2YKnKXUeGERi9yCLTO2C3t': [1],
#   '2e7mHNFlXCkFdKjJ3nsK9E': [1],
#   '2hSiACXW5Nt0yUxWUsoIpU': [1],
#   '2vAbKDdqA6cEBHU9zQiA8g': [1],
#   '4F4neui0edP1ozygvFiCi7': [1],
#   '5X48562lzIHeCKKLLSIGMm': [1],
#   '6dQJI4hFolhMnZhSHxkuGc': [1],
#   '6jL1SnyXcXiKOmw4M2RnmT': [1],
#   '6tZAvhrqkVhwFgptDHz5Wr': [1],
#   '7x7kYJwduClF3I0ozJpNsZ': [1]},
#  'johnny': {'0HjiQYZdHqrKyfeQL3JYw3': [0],
#   '0I0VDjGtm7F1lu5UiinV1b': [0],
#   '0Z9FRM5zukGVagh8TVSdrI': [0],
#   '0u4kWPHGLCnNhV1OlDxvpD': [0],
#   '0vsRt9W2VisbZW6mqqjbp8': [0],
#   '1F9dkdIZdlSFekJrvjQMe7': [0],
#   '1OK4hVcucqYKMU9Ipb3dtx': [0],
#   '1QMmvLfNQOQ2OFtvn3psmj': [0],
#   '1wa0Tm0MFcIpSdzILgQnmm': [0],
#   '2ZoGSx11fDWZRbVTAJrs1P': [0],
#   '3HGE6Is63CrKHS9DZ26RIO': [0],
#   '3W6WaJa1wRQfbhqotaHtyM': [0],
#   '3X3uYrKpdiBJmtJHG9oDT5': [0],
#   '3czEbp9uVLR9bmtoshfcj5': [0],
#   '3p7byaSR5J1he8vvDkxirp': [0],
#   '40xz60ciGIpsRtDqRfPKBE': [0],
#   '4VE3jasMCphS1duMN6RNNB': [0],
#   '68hsfx3ZutyxvSUCiNQ8sB': [0],
#   '6PeUPMMz3cskGSKCDbfDVq': [0],
#   '76LIYXBETh3PyHoNUufycb': [0],
#   '76vQiDLhpXk4LjW8dML1wT': [0],
#   '7a35kVTnsXzlplOrxOIN9W': [0],
#   '7aJ5Hx4GXT1pTTrPRkeKv9': [0]},
#  'gill': {'0HjiQYZdHqrKyfeQL3JYw3': [1],
#   '0Z9FRM5zukGVagh8TVSdrI': [1],
#   '0u4kWPHGLCnNhV1OlDxvpD': [1],
#   '1F9dkdIZdlSFekJrvjQMe7': [1],
#   '1QMmvLfNQOQ2OFtvn3psmj': [1],
#   '1wa0Tm0MFcIpSdzILgQnmm': [1],
#   '2ZoGSx11fDWZRbVTAJrs1P': [1],
#   '3HGE6Is63CrKHS9DZ26RIO': [1],
#   '40xz60ciGIpsRtDqRfPKBE': [1],
#   '4VE3jasMCphS1duMN6RNNB': [1],
#   '76LIYXBETh3PyHoNUufycb': [1],
#   '76vQiDLhpXk4LjW8dML1wT': [1],
#   '7a35kVTnsXzlplOrxOIN9W': [1]},
#  'crooks': {'0Hk1zuUABam9U5M634R0Fv': [1], '2jPTHZHHoUJiID90LEYV28': [1]},
#  'muna': {'0hKbBE3RwBZQtsnkzBIxIR': [0], '69WAiCaEdxACKzB4B7Bv27': [0]},
#  'raheem': {'0HkcFsicQMIumVpNNde204': [0],
#   '0rcuDEcrzF4Zo6ZbUEhaIn': [0],
#   '0wjo8DmCAqZ1q3lVLCyrRG': [0],
#   '18LxLNSgnkXRpijvMTdVtK': [0],
#   '5M1tzhbcYFY8DwPFDLSJXG': [0],
#   '5tUXQvc0yMQD42799A1mec': [0],
#   '6EqT8NTv64FId3JvxBe7mP': [0],
#   '6g9FyBtYg9qnpF2IP1Cd0J': [0],
#   '7BW60EnubNl94HnwcuB0E0': [0],
#   '7aON8z3MgEECzYwTSqakXZ': [0]},
#  'devaughn': {'0HkcFsicQMIumVpNNde204': [1],
#   '0rcuDEcrzF4Zo6ZbUEhaIn': [1],
#   '0wjo8DmCAqZ1q3lVLCyrRG': [1],
#   '18LxLNSgnkXRpijvMTdVtK': [1],
#   '5M1tzhbcYFY8DwPFDLSJXG': [1],
#   '5tUXQvc0yMQD42799A1mec': [1],
#   '6EqT8NTv64FId3JvxBe7mP': [1],
#   '6g9FyBtYg9qnpF2IP1Cd0J': [1],
#   '7BW60EnubNl94HnwcuB0E0': [1],
#   '7aON8z3MgEECzYwTSqakXZ': [1]},
#  'cochrane': {'0hKF8N8aflF1uDzEEnPr2j': [1]},
#  'möwe': {'0HkwDCJIbWijtfKg63gQBJ': [0],
#   '2sxkZzVmVYdyMaVghmyxn3': [0],
#   '3xmHwSfXvnqd74HjQHtMoz': [0],
#   '59bem62WIxhdH76jIWEm6S': [0]},
#  'olly': {'0HLpIMwRnkDSn55nAhscB9': [0],
#   '0Kvb0cKIssQg1t7c5KCw0k': [0],
#   '116uqdetf6JQtnnlYsyBfa': [0],
#   '2kg9AijbBp9HrXjlxByPT3': [0],
#   '3Nbcx1svCSzmyYG2I81YCZ': [0],
#   '4jOtC832PyIXlCVPRElfQu': [0],
#   '6q9hemM78FDsDJ2CHxpV5N': [0],
#   '79XW8ctYhU4Wq0iOx3NGjG': [0]},
#  'murs': {'0HLpIMwRnkDSn55nAhscB9': [1],
#   '3Nbcx1svCSzmyYG2I81YCZ': [1],
#   '4jOtC832PyIXlCVPRElfQu': [1],
#   '6q9hemM78FDsDJ2CHxpV5N': [1]},
#  'moonchild': {'0SsL24tWTdMshmTBhK95HV': [0],
#   '0Y0JVqSlj8J512B5kjKekP': [0],
#   '0hMmCpvgtjF8ZUsbl2x0Cg': [0],
#   '2xw83SYMla3pwGna8llGWi': [0],
#   '5NbdN6rPwkntsk9rdHO4vl': [0]},
#  'clapton': {'0hMNAUx9fFBdYQRO5FoQvL': [1],
#   '10LWVafpsc00GjdXTQqITk': [1],
#   '1oar8gdDX5yHWzVstAHDav': [1],
#   '2LxUVIA86AjulMdEDQT8DX': [1],
#   '2pQ6i5Ll6ggtG5T4RK5J9G': [1],
#   '2udGjDmpK1dH9VGyw7nrei': [1],
#   '2wEyJ0yjLLuE8Nk74vvqZC': [1],
#   '3ykSdTGmYPFl8pDBXer1zG': [1],
#   '4dYLOPfFc3mAErEJwr2Oo2': [1],
#   '5Pjx3qeo3aCwSYQ6R3yMzE': [1],
#   '612VcBshQcy4mpB2utGc3H': [1],
#   '6YEOmCsXSk9ZPE0FkcCiuQ': [1],
#   '6hDegaGv8VwBoMhGqoPfxR': [1]},
#  'voidz': {'0hmxVkpxbcdHAXUoZ7DeCQ': [1], '31u6rUeIEXGrYVoh10U7eu': [1]},
#  'petit': {'0hNduWmlWmEmuwEFcYvRu1': [0], '3WRQUvzRvBDr4AxMWhXc5E': [0]},
#  'biscuit': {'0hNduWmlWmEmuwEFcYvRu1': [1], '3WRQUvzRvBDr4AxMWhXc5E': [1]},
#  'drew': {'0hOAqVCzjzNpZgZZmt30HE': [0]},
#  'ryan': {'0hOAqVCzjzNpZgZZmt30HE': [1],
#   '0lLDaAdXcjOQ7Mf2NXzXay': [2],
#   '1CmUZGtH29Kx36C1Hleqlz': [2],
#   '1UdrrivJs5pW7WqKbUlDgl': [0],
#   '1lCfZOuD64LR9J1woSivou': [1],
#   '2gWQzeOzv9zDob2zeo5b1G': [0],
#   '2oVqzEcaXpUnxQv7dIAtKb': [0],
#   '39bipb25GobAR4QtYISUcw': [3],
#   '3AYcyxEACnmE6d96RPubID': [2],
#   '3bidbhpOYeV4knp8AIu8Xn': [2],
#   '3dQ71J2HPHXpPqJ0tQdDHR': [1],
#   '3o8bovLXjsxsFBTXajm1VA': [1],
#   '3u0n1VYwUNQyqiQTzJwwlL': [2],
#   '4YMqbFcDIFiCBd02PzUBcM': [2],
#   '56LYsQITV7nEggGBVuu846': [2]},
#  'dermot': {'0OGNtqKkjI7FCE9HZ4Khgo': [0],
#   '0hpaWop2LUln6yJ7b0eOza': [0],
#   '4Ta3PhWmY50ZLU1uhKFKPE': [0],
#   '6UjZ2Yx2g2a52XxiA8ONxZ': [0]},
#  'kennedy': {'0OGNtqKkjI7FCE9HZ4Khgo': [1],
#   '0hpaWop2LUln6yJ7b0eOza': [1],
#   '4Ta3PhWmY50ZLU1uhKFKPE': [1],
#   '4aMmKA1UvUhgWtimHnYIpA': [1],
#   '6UjZ2Yx2g2a52XxiA8ONxZ': [1],
#   '7gYtzSmzGgpO0WygzfJroD': [1]},
#  'kesha': {'0HPD5WQqrq7wPWR7P7Dw1i': [0],
#   '2bR6LkOC10pZ3udHdZiENF': [0],
#   '3Ex5RFJRUdpHcDOLXJOVLy': [0],
#   '3LUWWox8YYykohBbHUrrxd': [0],
#   '3MFQiTzOI5txaTQlybipNx': [0],
#   '5OMwQFBcte0aWFJFqrr5oj': [0],
#   '6mnjcTmK8TewHfyOp3fC9C': [0],
#   '6vc2Jq2vaGu8z326kSrw92': [0],
#   '7EQGXaVSyEDsCWKmUcfpLk': [0],
#   '7lWUJpax919G4JdaFEVmCy': [0]},
#  'ace': {'0hrBpAOgrt8RXigk83LLNE': [0],
#   '12BbMJsJi65mxneq6c9Lm7': [0],
#   '1GwdUrz7DujSedNxnzVfqI': [0],
#   '3DYVWvPh3kGwPasp7yjahc': [0],
#   '3P6fS71hWhZvOnnxQojJ0Z': [2],
#   '40CzF4QRkG1XAYonnuNeVp': [1],
#   '4AjKVyNUMdUveKK5OH1OJD': [0],
#   '4QUUmoiuVPfRUrYHfnL5B5': [0]},
#  'base': {'0hrBpAOgrt8RXigk83LLNE': [2],
#   '12BbMJsJi65mxneq6c9Lm7': [2],
#   '1GwdUrz7DujSedNxnzVfqI': [2],
#   '3DYVWvPh3kGwPasp7yjahc': [2]},
#  'knox': {'0HsE2zUH1uZg7Bnsjf51TM': [0], '5tvOiucEIc6W7ocHin5rFz': [0]},
#  'garrix': {'0HSHOXIDMwhFbXHnaxpvxE': [1],
#   '0OlnLZY4cmQzT6ZGttvWBM': [1],
#   '2E0fhpXbNfksy2mdjm57bf': [0],
#   '2ERoiswcZQdXztyYNODB4z': [0],
#   '34D6mvDTAPypm92EPs8Rxa': [0],
#   '4JIo8RztBbELr2gWJ5OGK6': [0],
#   '5bBrbeCtAntjU0SOUXnIC8': [0],
#   '5jlsg7onynIipVy5krMaRZ': [0],
#   '5ptH9OIrv5HW9s6BGjr7Np': [0],
#   '5y6pj7OeBFF0CVgZKhRbOG': [0],
#   '6oG7bmUn7ws0qYEJ0eEbeG': [0],
#   '6qb0O5HW7H4q6R0AbP38Ko': [0],
#   '6rrTr2HEAzlpC4KWZxF3S1': [0],
#   '6wZ8kvKP9d1MKlNFTMZrBK': [0],
#   '7rWLRWfPsUzU6h7r71vlOM': [0]},
#  'giants': {'0hsMhZA3gguNuHOcDsGmOf': [1]},
#  'tonyi': {'0HsTJZWuj9vY7Ns0If1ARm': [0],
#   '0Jl85WX8qBm0Ay9MrwUS1d': [0],
#   '1DBtVHYl2lwLQswEUvkIEv': [0],
#   '1DvFERTMTHRpLw2hKiqz3h': [0],
#   '2AmCvxADlZLK4xX47VezOR': [0],
#   '2VAK1wpNtziRwQrJxg0eQe': [0],
#   '2dbet87FbAhXTJPcTuJ2lK': [0],
#   '4cRR2gUTOerkUOW5iZpm91': [0],
#   '4chxiKYwSBoE0pvO4Ea0uv': [0],
#   '5i35AlocQnfyJjFiWVs3JF': [0],
#   '5oPRLER8bCQN3RFFVvLbTC': [0],
#   '6PViGgcsQhLPSkMxgoRWLl': [0],
#   '7M4CRFWgCuqYOuh5Kz1hm5': [0]},
#  'tonii': {'0HsTJZWuj9vY7Ns0If1ARm': [1],
#   '0Jl85WX8qBm0Ay9MrwUS1d': [1],
#   '1DBtVHYl2lwLQswEUvkIEv': [1],
#   '1DvFERTMTHRpLw2hKiqz3h': [1],
#   '2AmCvxADlZLK4xX47VezOR': [1],
#   '2VAK1wpNtziRwQrJxg0eQe': [1],
#   '2dbet87FbAhXTJPcTuJ2lK': [1],
#   '4cRR2gUTOerkUOW5iZpm91': [1],
#   '4chxiKYwSBoE0pvO4Ea0uv': [1],
#   '5i35AlocQnfyJjFiWVs3JF': [1],
#   '5oPRLER8bCQN3RFFVvLbTC': [1],
#   '6PViGgcsQhLPSkMxgoRWLl': [1],
#   '7M4CRFWgCuqYOuh5Kz1hm5': [1]},
#  'tonéi': {'0HsTJZWuj9vY7Ns0If1ARm': [2],
#   '0Jl85WX8qBm0Ay9MrwUS1d': [2],
#   '1DBtVHYl2lwLQswEUvkIEv': [2],
#   '1DvFERTMTHRpLw2hKiqz3h': [2],
#   '2AmCvxADlZLK4xX47VezOR': [2],
#   '2VAK1wpNtziRwQrJxg0eQe': [2],
#   '2dbet87FbAhXTJPcTuJ2lK': [2],
#   '4cRR2gUTOerkUOW5iZpm91': [2],
#   '4chxiKYwSBoE0pvO4Ea0uv': [2],
#   '5i35AlocQnfyJjFiWVs3JF': [2],
#   '5oPRLER8bCQN3RFFVvLbTC': [2],
#   '6PViGgcsQhLPSkMxgoRWLl': [2],
#   '7M4CRFWgCuqYOuh5Kz1hm5': [2]},
#  'destiny': {'0HUeFoQFiMUPKxFApxyPwL': [0],
#   '2gSyc23Hua25fqSFpgAh6W': [0],
#   '4myV8ss5IG0PtiIhmx99Bd': [0],
#   '4pmc2AxSEq6g7hPVlJCPyP': [0],
#   '6u5m71WNIGQCbhu95T4GVS': [0],
#   '6uYAPqxP69zfpCbsTHXgiz': [0],
#   '7H6ev70Weq6DdpZyyTmUXk': [0]},
#  'rogers': {'0HUeFoQFiMUPKxFApxyPwL': [1],
#   '2jPskMhww8DEwvOB7KmYAB': [1],
#   '4HfLQJtVT1KiX1eVedDyTm': [1],
#   '5sn1BmEOPP1bu4cZq9OgoF': [1],
#   '6u5m71WNIGQCbhu95T4GVS': [1],
#   '7g4V1MvSEquPXPJ2zN2lbz': [1]},
#  'maddix': {'0hur9YKoUq3uwte8K30zlC': [0],
#   '0lTIMAG4gTMux3zh5RvMKZ': [0],
#   '3gM00KjzFqb375IGk7FyWL': [0],
#   '4CaXP6LI8yatFKRQONlVvX': [0]},
#  'amy': {'0HvrW09sl0aoAEmlIcZ9s6': [0],
#   '0LbK1bodGLc9xmV1cS9jvL': [0],
#   '1L5tZi0izXsi5Kk5OJf4W0': [0],
#   '3irumzUB7UlJqoVZCqR3kI': [0],
#   '3jP3coGrROR7kjiDlpoRph': [0],
#   '4d0dY3ZeMdoYrD5YmdFvWZ': [0],
#   '4zQuwW24dweWcaX0fEJkP2': [0],
#   '5LC7nItIEFp4nzdFdEGbf9': [0],
#   '6CQaVuICm1WVXyy3SZ5jEI': [0],
#   '6viJumjXFeskzT8HBjhMe9': [0],
#   '7or26qS3BfpTtWO3BFw5GE': [0]},
#  'winehouse': {'0HvrW09sl0aoAEmlIcZ9s6': [1],
#   '0LbK1bodGLc9xmV1cS9jvL': [1],
#   '1L5tZi0izXsi5Kk5OJf4W0': [1],
#   '3irumzUB7UlJqoVZCqR3kI': [1],
#   '3jP3coGrROR7kjiDlpoRph': [1],
#   '4d0dY3ZeMdoYrD5YmdFvWZ': [1],
#   '4zQuwW24dweWcaX0fEJkP2': [1],
#   '5LC7nItIEFp4nzdFdEGbf9': [1],
#   '6CQaVuICm1WVXyy3SZ5jEI': [1],
#   '6viJumjXFeskzT8HBjhMe9': [1],
#   '7or26qS3BfpTtWO3BFw5GE': [1]},
#  'channel': {'0hvxqftYCZT406ElE03giM': [0]},
#  'live': {'0hvxqftYCZT406ElE03giM': [1],
#   '2VFRnfx3nzHdeSrFhtq9Jj': [0],
#   '384MzPWC7HLmPNYDrkYlj8': [1],
#   '7MJTU6jULOZPAdlu8SPAfo': [1]},
#  'ynw': {'0hwkukpHcBJfGcIUxi1tK2': [0],
#   '1iSqfoUFnQwV0QW1EfUit8': [0],
#   '66FltlEV09mPJYAyfYm8De': [0],
#   '6vWEAOUSxohKxhp0K1BsxL': [0],
#   '7eBqSVxrzQZtK2mmgRG6lC': [0]},
#  'melly': {'0hwkukpHcBJfGcIUxi1tK2': [1],
#   '1iSqfoUFnQwV0QW1EfUit8': [1],
#   '66FltlEV09mPJYAyfYm8De': [1],
#   '6vWEAOUSxohKxhp0K1BsxL': [1],
#   '7eBqSVxrzQZtK2mmgRG6lC': [1]},
#  'hale': {'0HZ3OUVrGHxttD2EuHqRm3': [0],
#   '6DswnRwL3rihiXeTGYPZ2m': [1],
#   '6IvOCyrwW7VuCjQFCD7h7r': [1]},
#  '5th': {'0HZlND4giwzgolBpaNIRGV': [1],
#   '4RFlr5gH4GDQrYjpP2fXw6': [0],
#   '5NLDqBWjQUdmmA9JDABiIb': [0]},
#  'dimension': {'0HZlND4giwzgolBpaNIRGV': [2]},
#  'then': {'0I0CVZi0p78WJMDftfXeGM': [0], '7BCrpOMsSnVpDgzQefNsyH': [0]},
#  'jerico': {'0I0CVZi0p78WJMDftfXeGM': [1], '7BCrpOMsSnVpDgzQefNsyH': [1]},
#  'kooks': {'0I0onONP8E5RG8oxpWoGIY': [1],
#   '2j9JpBQk7VhzYDOqToxhlA': [1],
#   '3Dgm3Eaw7mBjYrGxdZxfjl': [1],
#   '3hyi4CYvZ3K6EqAI2ja7pl': [1],
#   '5Msytfzyrxcaj5mjs3M19e': [1],
#   '6gGSSrKMiV2yec1DrqGhhy': [1],
#   '7FBLrEKnmvRCuVeozHEA01': [1]},
#  'kemp': {'0I0VDjGtm7F1lu5UiinV1b': [1],
#   '0otWaD7P1jqYsb0qSHNo6J': [1],
#   '1OK4hVcucqYKMU9Ipb3dtx': [1],
#   '7aJ5Hx4GXT1pTTrPRkeKv9': [1]},
#  'velvet': {'0i19MAZbyn8uTir7FprXId': [1],
#   '11VwZwNF29HrqwalYUMitb': [1],
#   '1o6DclZHw0HomxXEQR1ijX': [1],
#   '2g4LWy7YxrbWYA2RJP8nFk': [1],
#   '3CYH422oy1cZNoo0GTG1TK': [1],
#   '3lX49Bqy21Y5HneUJ7p55G': [1],
#   '5XJEdVQ5jl3C3dFsV7kCTZ': [1],
#   '7kF1iPJTj3VFJX9XokQ80F': [0]},
#  'underground': {'0i19MAZbyn8uTir7FprXId': [2],
#   '11VwZwNF29HrqwalYUMitb': [2],
#   '1o6DclZHw0HomxXEQR1ijX': [2],
#   '2g4LWy7YxrbWYA2RJP8nFk': [2],
#   '2z1FmK5To9gj1rU4mS20f9': [1],
#   '34MRi5GRWHFUa731JBxFEl': [3],
#   '3FygJnwLJbaU5xe4E87h8e': [1],
#   '3OcQkcvTcohs8vO8Rd3sKF': [1],
#   '3UhwS81S9L7i2byZCrhSAv': [3],
#   '3Ye7HMeHdQqpyCkhkGckYu': [1],
#   '3lX49Bqy21Y5HneUJ7p55G': [2],
#   '4WxQGUmWBRNovxlF2g8Xdv': [1]},
#  'gostan': {'0i3utbege8Iy3q7Hy86QCF': [0]},
#  'retrovision': {'0I3wlS5dlpw0hv5zhxN0pz': [0], '6Wmi08VTuMIAivClvxXyRK': [0]},
#  ...}

# %% [markdown]
# ### Find song based on artist

# %%
def positional_intersect(prev_word,next_word):
  intersect_id = set()
  for doc_id_1 in prev_word.keys():
    if doc_id_1 in next_word.keys():
      for doc_pos in prev_word[doc_id_1]:
        if doc_pos+1 in next_word[doc_id_1]:
          intersect_id.add(doc_id_1)
  return intersect_id

def get_query(kalimat,token_dict):
  token = nltk.tokenize.word_tokenize(kalimat.lower())
  if len(token) == 1:
    hasil = token_dict[token[0]].keys()
    return hasil  
  token_hasil = token[1:]
  hasil = token_dict[token[0]].keys()
  temp_word = token[0]
  for word in token_hasil:
      hasil = hasil & positional_intersect(token_dict[temp_word],token_dict[word])
      temp_word = word
  return hasil

def retrieve_result_artist(kalimat,token=index_artist, lyrics=False):
  kalimat = spell_check_artist(nltk.tokenize.word_tokenize(kalimat))
  id_set = get_query(kalimat,token)
  artist_result = pd.DataFrame()
  artist_result = sorted[sorted['track_id'].isin(id_set)]
  artist_result = artist_result.sort_values(by='track_popularity', ascending=False)
  if lyrics:
    return artist_result
  return artist_result.head(10)

# %%
get_query("suicideboys",index_artist)
# Out:
# dict_keys(['0fyBYsrmpihh1mfalssDlB', '0kCfKToIFZFQQAaSQHcjRL', '0NurtsK6qk4qwDfxmfC2YL', '2Bkfvi3pCcwoJwnmd45OnA', '2I12vOWeJU5ayhr6ha6esf', '3bNCifwGPjqeeqzpjrFG9k', '3mRBSk7h2Vr0D0yott8VhC', '3NSgQjYihV40pOmn8AQevz', '3SCVHoGHV7GL0hmqcOIpqh', '4irYeuAi87yyGHcI4h9s0x', '4LfZGbBkFJW0KF44vNoVjU', '4owRIrDAJPqNWGf2SGC3H8', '4XQDrALwqj4J1YPqg58sDV', '4yORBk6ZyYsJpnJchyZevc', '5XAPpyIoYF3QXP34Hv8Pvx', '6oyeeA0sHwHM1pPpZaIsrD', '6yK9kwo8cBoVRNOylq0yNc', '70nmZhHZLNVYWP4NON41Zw', '7ae2GdeXS5Tvo5RvdNwgaz', '7pu5jnOlS1k4fmigtRaXvG'])

# %%
x = retrieve_result_artist("ed sheeran")
x
# Out:
#                      track_id  ... track_popularity
# 11508  4vUmTMuQqjdnvlZmAH61Qk  ...               91
# 8064   3HVWdVOQ0ZA45FuZGSfvns  ...               90
# 10213  4evmHXcjt3bTUHD1cvny97  ...               89
# 1871   0tgVpDi06FyKpA1z0VMD4v  ...               86
# 18071  7qiZfU4dY1lWllzX7mPBI3  ...               86
# 16549  70eFcWOvlMObDhURTqT4Fv  ...               85
# 3334   1HNkqx9Ahdgi1Ixy2xkKkL  ...               84
# 965    0hVXuCcriWRGvwMV1r5Yn9  ...               84
# 7236   34gCuhDGsG4bRPIf9bb02f  ...               83
# 379    0afhq8XCExXpqazXczTSve  ...               80
#
# [10 rows x 7 columns]

# %% [markdown]
# ## **[Boolean Model for song title]**

# %%
'''
What to do:
1. Tokenization
2. Indexing
3. Spell correction with jarrad coeff and edit distance
4. Creating a boolean model -> Using position of index to search certain query
'''
# Out:
# '\nWhat to do:\n1. Tokenization\n2. Indexing\n3. Spell correction with jarrad coeff and edit distance\n4. Creating a boolean model -> Using position of index to search certain query\n'

# %% [markdown]
# ### Indexing song title

# %%
def indexer(list_of_lists):
  #for making a index with the type of dictionary, made for title
  index = dict()
  for i in range(len(list_of_lists)):
    title = list_of_lists[i]
    for no in range(len(title)):
      token = title[no]
      if token not in index.keys():
        temp = dict()
        temp[i] = [no] 
        index[token] = temp
      else:
        if i in index[token].keys():
          index[token][i] += [no]
        else:
          index[token][i] = [no]
  return index

# %%
title_index = indexer(tok_title)

# %% [markdown]
# ### Spelling correction for song title

# %%
# !pip install autocorrect
# Out:
# Collecting autocorrect
#   Downloading https://files.pythonhosted.org/packages/35/31/aa5d4b54baafed2d0eef47e30d527ea60eb7357f11c3b5adc58262a3c693/autocorrect-2.5.0.tar.gz (622kB)
#      |████████████████████████████████| 624kB 18.8MB/s
# Building wheels for collected packages: autocorrect
#   Building wheel for autocorrect (setup.py) ... done
#   Created wheel for autocorrect: filename=autocorrect-2.5.0-cp37-none-any.whl size=621854 sha256=35aec1208a16ca8600a774b0727e4b342d38985f8b03fdf41f038854fd74a337
#   Stored in directory: /root/.cache/pip/wheels/1f/71/da/4a15028d25fbd5fb97fb76c5f76f0ad86f0caa69394dd7cfa7
# Successfully built autocorrect
# Installing collected packages: autocorrect
# Successfully installed autocorrect-2.5.0

# %%
from autocorrect import Speller
spell = Speller(lang='en')

def preprocess_input_with_spelling(q):
  query = q.lower()
  q_tok = nltk.tokenize.word_tokenize(query)
  q_tok = pd.Series(q_tok).apply(lambda x:expand_contractions(x))
  q_clean = []
  for i in q_tok:
    if str.isalnum(i):
      autocorrect = spell(i)
      q_clean.append(autocorrect)
  
  return q_clean

# %% [markdown]
# ### Find the intersection between query and title index

# %%
def find_intersection(query, index):
  keys = index.keys()
  q_clean = preprocess_input_with_spelling(query)
  set_of_indexes = []
  answer_indexes = []
  for token in q_clean:
    if token in keys:
      set_of_indexes.append(set(list(index[token])))

  if len(set_of_indexes) > 0:
    answer_indexes = set_of_indexes[0]
    for ind_set in set_of_indexes:
      answer_indexes = answer_indexes.intersection(ind_set)
  
  answer_indexes = list(answer_indexes)
  return answer_indexes[:10]

# %% [markdown]
# ### Find song based on title

# %%
def find_title(query, title_index=title_index, data=sorted):
  indx = find_intersection(query, title_index)
  answer = pd.DataFrame()
  if indx == []:
    answer = "Not Found"
    print(answer)
    return 0
  answer = sorted.iloc[indx]
  answer = answer.sort_values(by='track_popularity', ascending=False)                 
  return answer

# %%
find_title("firefly", title_index, sorted)
# Out:
# Not Found
# 0

# %%
find_title("!!!!!", title_index, sorted)
# Out:
# Not Found
# 0

# %%
len(sorted)
# Out:
# 15405

# %% [markdown]
# ## Input combination

# %% [markdown]
# ### Arist & Title

# %%
def retrieve_artist_title(q_artist, q_title):
  artist_filter = retrieve_result_artist(q_artist, lyrics=True)
  title_filter = find_title(q_title)
  #print(artist_filter)
  #print(title_filter)
  #merge results of the 2 querys 
  full_filter = pd.merge(artist_filter, title_filter, how='right', on=['track_artist', "track_name"])
  full_filter = full_filter.iloc[:, 0:7].dropna()
  full_filter.columns = artist_filter.columns
  return full_filter

# %%
retrieve_artist_title("ed sheeran", "shape of you")
# Out:
#                  track_id  ... track_popularity
# 0  7qiZfU4dY1lWllzX7mPBI3  ...             86.0
# 1  0FE9t6xYkqWXU2ahLh6D8X  ...             75.0
# 2  7qiZfU4dY1lWllzX7mPBI3  ...             86.0
# 3  0FE9t6xYkqWXU2ahLh6D8X  ...             75.0
# 4  5H7CwzYZ60e7w69tX4ivQN  ...             51.0
#
# [5 rows x 7 columns]

# %% [markdown]
# ### Artist & Lyric

# %%
# Jika artist and lyrics
def retrieve_artist_lyrics(q_artist, q_lyrics):
  artist_filter = retrieve_result_artist(q_artist, lyrics=True)
  full_filter = find_lyrics(q_lyrics, artist_filter)
  return full_filter

# %%
retrieve_artist_lyrics('linkin park', "Breaking the habit tonight")
# Out:
#                  track_id  ...      similarity
# 0  6n8TMVyFKoUmDc4apxceRD  ...   [[0.7039161]]
# 1  7oVEtyuv9NBmnytsCIsY5I  ...   [[0.6442048]]
# 2  60a0Rd6pjrkxjPbaKzXjfq  ...   [[0.6417858]]
# 3  2nLtzopw4rPReszdYBJU6h  ...  [[0.63986975]]
# 4  0UFDKFqW2oGspYeYqo9wjA  ...   [[0.6364451]]
# 5  1fLlRApgzxWweF1JTf8yM5  ...  [[0.63526183]]
# 6  0WrZxwjIBUL0VNN0AAblBQ  ...  [[0.63526183]]
# 7  3aYBjxTMvrEOP0A0UXg9ER  ...  [[0.63324594]]
# 8  3fjmSxt0PskST13CSdBUFx  ...   [[0.6326205]]
# 9  1d5UuboIPRMD4HaU3yycKC  ...   [[0.6326205]]
#
# [10 rows x 9 columns]

# %% [markdown]
# ### Title Lyric

# %%
def find_title_lyrics(q_title, q_lyrics):
  title_idx = indexer(tok_title)
  title_doc = find_title(q_title, title_idx, sorted)
  full_doc = find_lyrics(q_lyrics, title_doc)
  return full_doc

# %%
find_title_lyrics('in the endd', "in the end it doesn't even matter")
# Out:
#                  track_id  ...      similarity
# 0  60a0Rd6pjrkxjPbaKzXjfq  ...  [[0.85805565]]
# 1  2vyACbL11HoiWTcA6Ri7wU  ...  [[0.82758236]]
# 2  5Ztwhn7zR0q7wRe2ZZsrmN  ...   [[0.8063226]]
# 3  1faolBLC36cigtao56kZHM  ...   [[0.7773652]]
#
# [4 rows x 9 columns]

# %% [markdown]
# # **[Evaluation]**
#
# Test case dan perhitungan dilakukan di dokumen dokumentasi program

# %% [markdown]
# # Misc

# %%
def out_beautifier(doc):
    if isinstance(doc, int):
        return
    out = doc[['track_name', 'track_artist', 'lyrics', 'track_popularity','playlist_genre']]
    display(out)

# %% [markdown]
# # **[Main Program]**

# %%
def main():
  print('''Hello I am Music Checker(temp)\n 
  ''')
  while True:
    print('What do you want to do?\n1.Search\n2.Quit')
    try:
      opening = int(input())
      if opening == 2:
        print('Goodbye!')
        return 
      elif opening != 1:
        continue
    except:
      continue
      
    print("Please input the title of the song. (You can leave it blank if you don't know)")
    in_title = str(input())
    print("Please input the artist of the song. (You can leave it blank if you don't know)")
    in_artist = str(input())
    print("Please input part of the lyrics of the song. (You can leave it blank if you don't know)")
    in_lyrics = str(input()) 

    if in_title == '' and in_artist == '' and in_lyrics == '': # All blank
      print("You can't have it all blank")
      continue
    if in_title != '' and in_artist != '': #Artist & Title
      # call search in_title & in_artist
      out_beautifier(retrieve_artist_title(in_artist, in_title))
      continue
    if in_title != '' and in_artist == '' and in_lyrics != '': # Title & Lyric
      # call search in_title & in_lyrics
      out_beautifier(find_title_lyrics(in_title, in_lyrics))
      continue
    if in_title == '' and in_artist != '' and in_lyrics != '': # Artist & Lyric
      # call search in_artist & in_lyrics
      out_beautifier(retrieve_artist_lyrics(in_artist, in_lyrics))
      continue
    if in_title != '' and in_artist == '' and in_lyrics == '': # Title
      # Call search in_title
      out_beautifier(find_title(in_title))
      continue
    if in_title == '' and in_artist != '' and in_lyrics == '': # Artist
      out_beautifier(retrieve_result_artist(in_artist))
      # call search in_artist
      continue
    if in_title == '' and in_artist == '' and in_lyrics != '': # Lyric
      # call search in_lyrics
      out_beautifier(find_lyrics(in_lyrics))
      continue

# %% [markdown]
# # Test case

# %%
main() #Checking title only
# Out:
# Hello I am Music Checker(temp)
#
#
# What do you want to do?
# 1.Search
# 2.Quit
# 2
# Goodbye!

# %%
main() #Artist only
# Out:
# Hello I am Music Checker(temp)
#
#
# What do you want to do?
# 1.Search
# 2.Quit
# 1
# Please input the title of the song. (You can leave it blank if you don't know)
#
# Please input the artist of the song. (You can leave it blank if you don't know)
# taylor
# Please input part of the lyrics of the song. (You can leave it blank if you don't know)
#                                     track_name  ... playlist_genre
# 15892                    You Need To Calm Down  ...            pop
# 8078        Lover (Remix) [feat. Shawn Mendes]  ...            pop
# 9582                 I Forgot That You Existed  ...            r&b
# 4337                               Blank Space  ...            pop
# 14885                 I Knew You Were Trouble.  ...            pop
# 2062   We Are Never Ever Getting Back Together  ...            pop
# 3468                  Look What You Made Me Do  ...            pop
# 1672                          How You Want It?  ...            r&b
# 13562                                 Delicate  ...            edm
# 8503                             Gonna Love Me  ...            r&b
#
# [10 rows x 5 columns]
# What do you want to do?
# 1.Search
# 2.Quit
# 2
# Goodbye!

# %%
main() #Lirik only
# Out:
# Hello I am Music Checker(temp)
#
#
# What do you want to do?
# 1.Search
# 2.Quit
# 1
# Please input the title of the song. (You can leave it blank if you don't know)
#
# Please input the artist of the song. (You can leave it blank if you don't know)
#
# Please input part of the lyrics of the song. (You can leave it blank if you don't know)
# bad blood
#                   track_name  ... playlist_genre
# 0                    Bad Boy  ...           rock
# 1                      Blood  ...            rap
# 2                 Give Blood  ...           rock
# 3               Bad Medicine  ...           rock
# 4                      Blood  ...           rock
# 5                Bomb A Drop  ...            edm
# 6                       BAMF  ...            edm
# 7                  Bad Blood  ...           rock
# 8      It's Okay (One Blood)  ...            rap
# 9  Bad Blood - Alternate Mix  ...            rap
#
# [10 rows x 5 columns]
# What do you want to do?
# 1.Search
# 2.Quit
# 2
# Goodbye!

# %%
main() #Lirik & Artist
# Out:
# Hello I am Music Checker(temp)
#
#
# What do you want to do?
# 1.Search
# 2.Quit
# 1
# Please input the title of the song. (You can leave it blank if you don't know)
# blank space
# Please input the artist of the song. (You can leave it blank if you don't know)
# taylor
# Please input part of the lyrics of the song. (You can leave it blank if you don't know)
#     track_name  track_artist  ... track_popularity  playlist_genre
# 0  Blank Space  Taylor Swift  ...               78             pop
#
# [1 rows x 5 columns]
# What do you want to do?
# 1.Search
# 2.Quit
# 2
# Goodbye!

# %%
main() #Lirik & Title
# Out:
# Hello I am Music Checker(temp)
#
#
# What do you want to do?
# 1.Search
# 2.Quit
# 1
# Please input the title of the song. (You can leave it blank if you don't know)
# in the end
# Please input the artist of the song. (You can leave it blank if you don't know)
#
# Please input part of the lyrics of the song. (You can leave it blank if you don't know)
# even matter
#                                track_name  ... playlist_genre
# 0                              In the End  ...           rock
# 1  The Loser In The End - Remastered 2011  ...           rock
# 2                 In the End (Lost Tapes)  ...            pop
# 3                              In the End  ...           rock
#
# [4 rows x 5 columns]
# What do you want to do?
# 1.Search
# 2.Quit
# What do you want to do?
# 1.Search
# 2.Quit
# 2
# Goodbye!

# %%
main() #Title & Artist
# Out:
# Hello I am Music Checker(temp)
#
#
# What do you want to do?
# 1.Search
# 2.Quit
# 2
# Goodbye!

# %%
main() #Walkthrough
# Out:
# Hello I am Music Checker(temp)
#
#
# What do you want to do?
# 1.Search
# 2.Quit
# 2
# Goodbye!
